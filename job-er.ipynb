# %%
import pandas as pd
import re

# %%
job_df = pd.read_csv('job_post.csv')

# %%
job_df
# Out:
#         id                                 title                   company  \
# 0        1                        Data Scientist       Aquatic Informatics
# 1        2         Business Intelligence Analyst                   GLENTEL
# 2        3        Human Resources Data Scientist                 Rio Tinto
# 3        4  Lead - Human Resource Data Scientist                 Rio Tinto
# 4        5             Machine Learning Engineer  Skycope Technologies Inc
# ...    ...                                   ...                       ...
# 1445  1456        Human Resources Data Scientist                 Rio Tinto
# 1446  1457  Lead - Human Resource Data Scientist                 Rio Tinto
# 1447  1458               Principal Data Engineer                FreshBooks
# 1448  1459                         Data Engineer              Prodigy Game
# 1449  1460                         Data Engineer             autoTrader.ca
#
#            location                                        description  \
# 0     Vancouver, BC  Do you want a meaningful role in a company tha...
# 1       Burnaby, BC  Brand: Glentel Corporate\nLocation: Burnaby Of...
# 2            Canada  2 x newly created Data Scientist opportunities...
# 3            Canada  Newly created data science lead embedded withi...
# 4     Vancouver, BC  Who We are\nFounded in 2016, Skycope Technolog...
# ...             ...                                                ...
# 1445         Canada  2 x newly created Data Scientist opportunities...
# 1446         Canada  Newly created data science lead embedded withi...
# 1447        Toronto  FreshBooks has a big vision. We launched in 20...
# 1448       Oakville  Prodigy Education connects students, parents, ...
# 1449        Toronto  Prodigy Education connects students, parents, ...
#
#              source       search_kw
# 0        indeed.com  data scientist
# 1        indeed.com  data scientist
# 2        indeed.com  data scientist
# 3        indeed.com  data scientist
# 4        indeed.com  data scientist
# ...             ...             ...
# 1445     indeed.com  data scientist
# 1446     indeed.com  data scientist
# 1447  glassdoor.com   data engineer
# 1448  glassdoor.com   data engineer
# 1449  glassdoor.com   data engineer
#
# [1450 rows x 7 columns]

# %%
glassdoor_df = job_df.where(job_df.source=='glassdoor.com').dropna()
indeed_df = job_df.where(job_df.source=='indeed.com').dropna()

# %%
glassdoor_df.head(5)
# Out:
#           id                      title               company   location  \
# 1004  1015.0             Data Scientist              Unbounce  Vancouver
# 1005  1016.0  Machine Learning Engineer           PressReader   Richmond
# 1006  1017.0           Data Scientist I                Amazon  Vancouver
# 1007  1018.0             Data Scientist          Jungle Scout  Vancouver
# 1008  1019.0             Data Scientist  SkyHive Technologies  Vancouver
#
#                                             description         source  \
# 1004  We are looking for a Data Scientist to help us...  glassdoor.com
# 1005  PressReader is the “Netflix” of newspapers and...  glassdoor.com
# 1006  Terms of employment: Full time, permanent\n\nJ...  glassdoor.com
# 1007  Did you know that Jungle Scout collects and pr...  glassdoor.com
# 1008  The Opportunity\n\nDo you enjoy solving comple...  glassdoor.com
#
#            search_kw
# 1004  data scientist
# 1005  data scientist
# 1006  data scientist
# 1007  data scientist
# 1008  data scientist

# %%
indeed_df.head(5)
# Out:
#     id                                 title                   company  \
# 0  1.0                        Data Scientist       Aquatic Informatics
# 1  2.0         Business Intelligence Analyst                   GLENTEL
# 2  3.0        Human Resources Data Scientist                 Rio Tinto
# 3  4.0  Lead - Human Resource Data Scientist                 Rio Tinto
# 4  5.0             Machine Learning Engineer  Skycope Technologies Inc
#
#         location                                        description  \
# 0  Vancouver, BC  Do you want a meaningful role in a company tha...
# 1    Burnaby, BC  Brand: Glentel Corporate\nLocation: Burnaby Of...
# 2         Canada  2 x newly created Data Scientist opportunities...
# 3         Canada  Newly created data science lead embedded withi...
# 4  Vancouver, BC  Who We are\nFounded in 2016, Skycope Technolog...
#
#        source       search_kw
# 0  indeed.com  data scientist
# 1  indeed.com  data scientist
# 2  indeed.com  data scientist
# 3  indeed.com  data scientist
# 4  indeed.com  data scientist

# %%
def preprocess_df(df, cols):
    all_tokens=[]

    #Concatenate $cols in $df
    joined_val = df[cols[0]].map(str) + " " + df[cols[1]].map(str) + " " + df[cols[2]].map(str)

    #Tokenizer
    for string in joined_val:
        #Getting a set of tokens from each string in joined_val
        tokens = re.split(r'\W+',string.lower())
        tokens = list(filter(None,tokens))

        #Filtering unwanted values in each token list
        if 'nan' in tokens:
            tokens.remove('nan')
        all_tokens.append(tokens)

    #Adding a new column 'joinKey' with all tokens as values
    df['joinKey'] = all_tokens
    return df



def filtering(df1, df2):

    #Flattening the column values 
    df1_f = df1.explode('joinKey')
    df2_f = df2.explode('joinKey')

    #Renaming the column names as required
    df1_new = df1_f[['id','joinKey']].rename(columns={"id": "id1", "joinKey": "joinKey1"})
    df2_new = df2_f[['id','joinKey']].rename(columns={"id": "id2", "joinKey": "joinKey2"})

    #Joining the two dataframes on the condition that their joinKeys share at least one token 
    cand_df = df1_new.merge(df2_new, left_on=['joinKey1'], right_on=['joinKey2'])
    cand_df.drop_duplicates(subset=['id1','id2'],inplace=True)

    #Merging with original dataframes to get the unflattened column values
    cand_df = df1.merge(cand_df, left_on='id', right_on='id1')
    cand_df = df2.merge(cand_df, left_on='id', right_on='id2')

    cand_df = cand_df[['id1','joinKey_x','id2','joinKey_y']].\
              rename(columns={"joinKey_x": "joinKey1", "joinKey_y": "joinKey2"})
    return cand_df



def verification(cand_df, threshold):
    jacc = []
    result_df = pd.DataFrame()

    #Iterating through all the rows and converting it to set type
    for index,row in cand_df.iterrows():
        r = set(row['joinKey1'])
        s = set(row['joinKey2'])

        #Finding the jaccard distance of all record pairs (r,s)
        j = len(r.intersection(s)) / len(r.union(s))
        jacc.append(j)
    result_df['jaccard'] = jacc
    result_df = pd.concat([cand_df,result_df],axis=1)

    #Restoring only the rows which has jaccard value greater or equal to the threshold (0.5)
    result_df = result_df[result_df['jaccard'] >= threshold].reset_index().drop(['index'],axis=1)
    return result_df


def jaccard_join(cols1, cols2, threshold):
    new_df1 = preprocess_df(glassdoor_df, glassdoor_cols)
    new_df2 = preprocess_df(indeed_df, indeed_cols)
    print ("Before filtering: %d pairs in total" %(glassdoor_df.shape[0] *indeed_df.shape[0])) 

    cand_df = filtering(new_df1, new_df2)
    print ("After Filtering: %d pairs left" %(cand_df.shape[0]))

    result_df = verification(cand_df, threshold)
    print ("After Verification: %d similar pairs" %(result_df.shape[0]))

    return result_df


glassdoor_cols = ["title", "company","location"]
indeed_cols = ["title", "company","location"]
result_df = jaccard_join(glassdoor_cols, indeed_cols, 0.5)
# Out:
# Before filtering: 443256 pairs in total
# After Filtering: 312016 pairs left
# After Verification: 873 similar pairs
