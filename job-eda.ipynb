# %%
import pandas as pd
import sqlite3

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("collectors/data.sqlite3")
job_df = pd.read_sql_query("SELECT * from job_post", con)
company_review_df = pd.read_sql_query("SELECT * from company_review", con)
con.close()

# %%
# Verify that result of SQL query is stored in the dataframe
job_df.head()
# Out:
#    id                                            title  \
# 0   1  Data Scientist - Price Point – Start-up company
# 1   2                   Human Resources Data Scientist
# 2   3             Lead - Human Resource Data Scientist
# 3   4                                   Data Scientist
# 4   5                         Associate Data Scientist
#
#                                 company       location  \
# 0                      Groom & Associes  Vancouver, BC
# 1                             Rio Tinto         Canada
# 2                             Rio Tinto         Canada
# 3                           Visier Inc.  Vancouver, BC
# 4  TrainTurf Academic Solutions Limited  Vancouver, BC
#
#                                          description      source
# 0  This company is an e-retailer with a unique me...  indeed.com
# 1  2 x newly created Data Scientist opportunities...  indeed.com
# 2  Newly created data science lead embedded withi...  indeed.com
# 3  What you'll be doing...\nWhat you'll bring to ...  indeed.com
# 4  We are looking for a Data Scientist to support...  indeed.com

# %%
company_review_df.head()
# Out:
#    id     company                 title rating                   author  \
# 0   1  Air Canada  fun place to work at    5.0              Ramp Agent
# 1   2  Air Canada      Great workplace!    5.0       Station Attendant
# 2   3  Air Canada         Poor teamwork    1.0               Concierge
# 3   4  Air Canada          Good company    5.0       Reservation Agent
# 4   5  Air Canada   Great company but..    5.0  CABIN CREW MANAGER IFS
#
#       author_status         location             date  \
# 0   Former Employee     Toronto, ON    6 October 2019
# 1   Former Employee     Calgary, AB     10 March 2020
# 2   Former Employee   Vancouver, BC      9 March 2020
# 3  Current Employee    Montréal, QC      8 March 2020
# 4   Former Employee     Toronto, ON      3 March 2020
#
#                                          description      source
# 0  Air Canada is one of the best working environm...  indeed.com
# 1  Best place to work in Canada. Opportunities to...  indeed.com
# 2  Work environment very stressful. No real sense...  indeed.com
# 3  Good company to work with they have good benef...  indeed.com
# 4  AC is a great company but work where you have ...  indeed.com
