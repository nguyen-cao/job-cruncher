# %% [markdown]
# # Notebook to map job title and description with occupation and competency

# %%
import numpy as np
import pandas as pd
import sqlite3
import spacy

# %%
# Download pretrained enlgish model
try:
    import en_core_web_md
except:
    # !python -m spacy download en_core_web_md
    import en_core_web_md

# %%
# Read sqlite query results into a pandas DataFrame
home_path = "../../"
con = sqlite3.connect(home_path+"collectors/data.sqlite3")
job_df = pd.read_sql_query("SELECT * from job_post", con)
con.close()

# %%
# Verify that result of SQL query is stored in the dataframe
job_df.head()
# Out:
#    id                                 title                   company  \
# 0   1                        Data Scientist       Aquatic Informatics
# 1   2         Business Intelligence Analyst                   GLENTEL
# 2   3        Human Resources Data Scientist                 Rio Tinto
# 3   4  Lead - Human Resource Data Scientist                 Rio Tinto
# 4   5             Machine Learning Engineer  Skycope Technologies Inc
#
#         location                                        description  \
# 0  Vancouver, BC  Do you want a meaningful role in a company tha...
# 1    Burnaby, BC  Brand: Glentel Corporate\nLocation: Burnaby Of...
# 2         Canada  2 x newly created Data Scientist opportunities...
# 3         Canada  Newly created data science lead embedded withi...
# 4  Vancouver, BC  Who We are\nFounded in 2016, Skycope Technolog...
#
#        source       search_kw
# 0  indeed.com  data scientist
# 1  indeed.com  data scientist
# 2  indeed.com  data scientist
# 3  indeed.com  data scientist
# 4  indeed.com  data scientist

# %%
job_titles = job_df['title'].to_list()

# %%
job_titles = [title.lower() for title in job_titles]

# %%
nlp = en_core_web_md.load()

# %%
# Preprocess the text
def process_text(text):
    doc = nlp(text)
    result = []
    for token in doc:
        if token.text in nlp.Defaults.stop_words:
            continue
        if token.is_punct:
            continue
        if token.lemma_ == '-PRON-':
            continue
        # result.append(token.lemma_)
        result.append(token.text)
    return " ".join(result)
    # return result

# %%
# Process every document
for i in range(len(job_titles)):
    job_titles[i] = process_text(job_titles[i])

# %%
job_titles[0:5]
# Out:
# ['data scientist',
#  'business intelligence analyst',
#  'human resources data scientist',
#  'lead human resource data scientist',
#  'machine learning engineer']

# %%
onet_competencies = home_path+'datasets/competencies.csv'
onet_df = pd.read_csv(onet_competencies,index_col=0)
onet_df[onet_df['occupation'] == 'Computer and Information Research Scientists'].head(10)
# Out:
#                                      occupation  \
# 0  Computer and Information Research Scientists
# 1  Computer and Information Research Scientists
# 2  Computer and Information Research Scientists
# 3  Computer and Information Research Scientists
# 4  Computer and Information Research Scientists
# 5  Computer and Information Research Scientists
# 6  Computer and Information Research Scientists
# 7  Computer and Information Research Scientists
# 8  Computer and Information Research Scientists
# 9  Computer and Information Research Scientists
#
#                                           competency           category  \
# 0                Source code management SCM software  Technology Skills
# 1                                    Microsoft Azure  Technology Skills
# 2                                      Visualization          Abilities
# 3                                Free-field speakers         Tools Used
# 4                        Data visualization software  Technology Skills
# 5                       Judgment and Decision Making             Skills
# 6                                              Linux  Technology Skills
# 7                                  IBM Rational Apex  Technology Skills
# 8                                            Minitab  Technology Skills
# 9  Evaluate project plans and proposals to assess...    Task Statements
#
#                                          description
# 0                   Development environment software
# 1                   Development environment software
# 2  The ability to imagine how something will look...
# 3                                       Loudspeakers
# 4                  Analytical or scientific software
# 5  Considering the relative costs and benefits of...
# 6                          Operating system software
# 7                  Configuration management software
# 8                  Analytical or scientific software
# 9                                               Core

# %%
onet_occupations = home_path+'datasets/occupations.csv'
onet_oc_df = pd.read_csv(onet_occupations,index_col=0)
onet_oc_df.head(10)
# Out:
#    identifier                                               name  \
# 0  15-1111.00       Computer and Information Research Scientists
# 1  19-4061.00                 Social Science Research Assistants
# 2  19-2099.01        Remote Sensing Scientists and Technologists
# 3  19-1029.01                          Bioinformatics Scientists
# 4  15-1199.04  Geospatial Information Scientists and Technolo...
# 5  19-3022.00                                 Survey Researchers
# 6  15-2041.00                                      Statisticians
# 7  15-1121.00                          Computer Systems Analysts
# 8  15-2021.00                                     Mathematicians
# 9  15-1133.00              Software Developers, Systems Software
#
#                                          description  \
# 0  Conduct research into fundamental computer and...
# 1  Assist social scientists in laboratory, survey...
# 2  Apply remote sensing principles and methods to...
# 3  Conduct research using bioinformatics theory a...
# 4  Research or develop geospatial technologies. M...
# 5  Plan, develop, or conduct surveys. May analyze...
# 6  Develop or apply mathematical or statistical t...
# 7  Analyze science, engineering, business, and ot...
# 8  Conduct research in fundamental mathematics or...
# 9  Research, design, develop, and test operating ...
#
#                                               titles
# 0  Artificial Intelligence Specialist (AI Special...
# 1  Bilingual Research Interviewer,Clinical Resear...
# 2  All Source Intelligence Analyst,Data Analytics...
# 3  Assistant Scientist,Bioinformatician,Bioinform...
# 4  Geographic Information Scientist,Geographic In...
# 5  Data Analyst,Data Collection Specialist,Field ...
# 6  Analytical Statistician,Applied Scientist,Appl...
# 7  Applications Analyst,Applications Systems Anal...
# 8  Agent-Based Modeler,Algebraist,Applied Mathema...
# 9  Applications Analyst,Automation Engineer,Beta ...

# %%
voc_bigrams = home_path+'datasets/top_bigrams.csv'
voc_bigrams_df = pd.read_csv(voc_bigrams)
top_bigrams = voc_bigrams_df['description'].unique()
top_bigrams
# Out:
# array(['machine learning', 'data science', 'data scientist',
#        'computer science', 'data analytics', 'deep learning',
#        'experience working', 'big data', 'des données',
#        'advanced analytics', 'years experience', 'data sets',
#        'data analysis', 'communication skills', 'data scientists',
#        'experience data', 'problem solving', 'data driven',
#        'business intelligence', 'data visualization', 'data engineer',
#        'data pipelines', 'data engineering', 'equal opportunity',
#        'software development', 'opportunity employer', 'lehigh hanson',
#        'bachelor degree', 'degree computer', 'data analyst',
#        'ability work', 'et des', 'business analyst', 'business units',
#        'related field', 'fast paced', 'et la', 'skills ability', 'et les',
#        'job types'], dtype=object)

# %%
title_occupation = job_df.copy()
title_occupation['title_processed'] = job_titles
title_occupation['keyword_processed'] = title_occupation.apply(lambda row: [bigram for bigram in top_bigrams if bigram in row.description], axis=1)
title_occupation['title_processed'] = title_occupation.apply(lambda row: '{} {}'.format(row.title_processed, ' '.join(row.keyword_processed)), axis=1)
title_occupation.head(5)
# Out:
#    id                                 title                   company  \
# 0   1                        Data Scientist       Aquatic Informatics
# 1   2         Business Intelligence Analyst                   GLENTEL
# 2   3        Human Resources Data Scientist                 Rio Tinto
# 3   4  Lead - Human Resource Data Scientist                 Rio Tinto
# 4   5             Machine Learning Engineer  Skycope Technologies Inc
#
#         location                                        description  \
# 0  Vancouver, BC  Do you want a meaningful role in a company tha...
# 1    Burnaby, BC  Brand: Glentel Corporate\nLocation: Burnaby Of...
# 2         Canada  2 x newly created Data Scientist opportunities...
# 3         Canada  Newly created data science lead embedded withi...
# 4  Vancouver, BC  Who We are\nFounded in 2016, Skycope Technolog...
#
#        source       search_kw  \
# 0  indeed.com  data scientist
# 1  indeed.com  data scientist
# 2  indeed.com  data scientist
# 3  indeed.com  data scientist
# 4  indeed.com  data scientist
#
#                                      title_processed  \
# 0  data scientist machine learning data science c...
# 1  business intelligence analyst data science dat...
# 2  human resources data scientist machine learnin...
# 3  lead human resource data scientist machine lea...
# 4  machine learning engineer machine learning dat...
#
#                                    keyword_processed
# 0  [machine learning, data science, computer scie...
# 1  [data science, data analytics, years experienc...
# 2  [machine learning, data science, computer scie...
# 3  [machine learning, data science, computer scie...
# 4  [machine learning, data science, deep learning...

# %%
# Process every document
occupation_titles =  onet_oc_df['titles'].to_list()
for i in range(len(occupation_titles)):
    occupation_titles[i] = [process_text(title.lower()) for title in occupation_titles[i].split(',')]

# %%
onet_oc_df['titles_processed'] = occupation_titles

# %%
onet_oc_df.head(10)
# Out:
#    identifier                                               name  \
# 0  15-1111.00       Computer and Information Research Scientists
# 1  19-4061.00                 Social Science Research Assistants
# 2  19-2099.01        Remote Sensing Scientists and Technologists
# 3  19-1029.01                          Bioinformatics Scientists
# 4  15-1199.04  Geospatial Information Scientists and Technolo...
# 5  19-3022.00                                 Survey Researchers
# 6  15-2041.00                                      Statisticians
# 7  15-1121.00                          Computer Systems Analysts
# 8  15-2021.00                                     Mathematicians
# 9  15-1133.00              Software Developers, Systems Software
#
#                                          description  \
# 0  Conduct research into fundamental computer and...
# 1  Assist social scientists in laboratory, survey...
# 2  Apply remote sensing principles and methods to...
# 3  Conduct research using bioinformatics theory a...
# 4  Research or develop geospatial technologies. M...
# 5  Plan, develop, or conduct surveys. May analyze...
# 6  Develop or apply mathematical or statistical t...
# 7  Analyze science, engineering, business, and ot...
# 8  Conduct research in fundamental mathematics or...
# 9  Research, design, develop, and test operating ...
#
#                                               titles  \
# 0  Artificial Intelligence Specialist (AI Special...
# 1  Bilingual Research Interviewer,Clinical Resear...
# 2  All Source Intelligence Analyst,Data Analytics...
# 3  Assistant Scientist,Bioinformatician,Bioinform...
# 4  Geographic Information Scientist,Geographic In...
# 5  Data Analyst,Data Collection Specialist,Field ...
# 6  Analytical Statistician,Applied Scientist,Appl...
# 7  Applications Analyst,Applications Systems Anal...
# 8  Agent-Based Modeler,Algebraist,Applied Mathema...
# 9  Applications Analyst,Automation Engineer,Beta ...
#
#                                     titles_processed
# 0  [artificial intelligence specialist ai special...
# 1  [bilingual research interviewer, clinical rese...
# 2  [source intelligence analyst, data analytics c...
# 3  [assistant scientist, bioinformatician, bioinf...
# 4  [geographic information scientist, geographic ...
# 5  [data analyst, data collection specialist, fie...
# 6  [analytical statistician, applied scientist, a...
# 7  [applications analyst, applications systems an...
# 8  [agent based modeler, algebraist, applied math...
# 9  [applications analyst, automation engineer, be...

# %% [markdown]
# ## Two methods to calculate the similarity
# ### 1. Calculate job title similarity with all the alternate titles for each occupation in ONet
# ### 2. Calculate job title similarity with each alternate title for each occupation in ONet, and store maximum similarty score valued title

# %%
import itertools

df1 = title_occupation[['id', 'title', 'title_processed']]
df2 = onet_oc_df[['identifier', 'titles_processed']]

df_vals = list(itertools.product(df1.values.tolist(),df2.values.tolist()))
colnames = list(df1.columns) + list(df2.columns)
score_df = pd.DataFrame(list(map(lambda x : sum(x,[]), df_vals)), columns=colnames)
score_df.head(10)
# Out:
#    id           title                                    title_processed  \
# 0   1  Data Scientist  data scientist machine learning data science c...
# 1   1  Data Scientist  data scientist machine learning data science c...
# 2   1  Data Scientist  data scientist machine learning data science c...
# 3   1  Data Scientist  data scientist machine learning data science c...
# 4   1  Data Scientist  data scientist machine learning data science c...
# 5   1  Data Scientist  data scientist machine learning data science c...
# 6   1  Data Scientist  data scientist machine learning data science c...
# 7   1  Data Scientist  data scientist machine learning data science c...
# 8   1  Data Scientist  data scientist machine learning data science c...
# 9   1  Data Scientist  data scientist machine learning data science c...
#
#    identifier                                   titles_processed
# 0  15-1111.00  [artificial intelligence specialist ai special...
# 1  19-4061.00  [bilingual research interviewer, clinical rese...
# 2  19-2099.01  [source intelligence analyst, data analytics c...
# 3  19-1029.01  [assistant scientist, bioinformatician, bioinf...
# 4  15-1199.04  [geographic information scientist, geographic ...
# 5  19-3022.00  [data analyst, data collection specialist, fie...
# 6  15-2041.00  [analytical statistician, applied scientist, a...
# 7  15-1121.00  [applications analyst, applications systems an...
# 8  15-2021.00  [agent based modeler, algebraist, applied math...
# 9  15-1133.00  [applications analyst, automation engineer, be...

# %%
# Method 1 - with all alternate titles together

nlp_title = np.array([nlp(title) for title in df1['title_processed']])
nlp_occupation_title = np.array([nlp(' '.join(title)) for title in df2['titles_processed']])
scores = np.array([title.similarity(occupation_title) \
                  for title in nlp_title \
                  for occupation_title in nlp_occupation_title])

# %%
score_df['score_all'] = scores
score_df.head(10)
# Out:
#    id           title                                    title_processed  \
# 0   1  Data Scientist  data scientist machine learning data science c...
# 1   1  Data Scientist  data scientist machine learning data science c...
# 2   1  Data Scientist  data scientist machine learning data science c...
# 3   1  Data Scientist  data scientist machine learning data science c...
# 4   1  Data Scientist  data scientist machine learning data science c...
# 5   1  Data Scientist  data scientist machine learning data science c...
# 6   1  Data Scientist  data scientist machine learning data science c...
# 7   1  Data Scientist  data scientist machine learning data science c...
# 8   1  Data Scientist  data scientist machine learning data science c...
# 9   1  Data Scientist  data scientist machine learning data science c...
#
#    identifier                                   titles_processed  score_all
# 0  15-1111.00  [artificial intelligence specialist ai special...   0.883895
# 1  19-4061.00  [bilingual research interviewer, clinical rese...   0.711012
# 2  19-2099.01  [source intelligence analyst, data analytics c...   0.812730
# 3  19-1029.01  [assistant scientist, bioinformatician, bioinf...   0.743133
# 4  15-1199.04  [geographic information scientist, geographic ...   0.838989
# 5  19-3022.00  [data analyst, data collection specialist, fie...   0.749849
# 6  15-2041.00  [analytical statistician, applied scientist, a...   0.820429
# 7  15-1121.00  [applications analyst, applications systems an...   0.818415
# 8  15-2021.00  [agent based modeler, algebraist, applied math...   0.789097
# 9  15-1133.00  [applications analyst, automation engineer, be...   0.766679

# %%
score_df = score_df.sort_values('score_all', ascending=False).drop_duplicates(['id'])
score_df = score_df.sort_values('id')
score_df.head(10)
# Out:
#      id                                 title  \
# 0     1                        Data Scientist
# 33    2         Business Intelligence Analyst
# 38    3        Human Resources Data Scientist
# 57    4  Lead - Human Resource Data Scientist
# 76    5             Machine Learning Engineer
# 95    6                        Data Scientist
# 114   7              Associate Data Scientist
# 133   8                      Data Scientist I
# 152   9              Data Scientist, AI@Unity
# 171  10                        Data Scientist
#
#                                        title_processed  identifier  \
# 0    data scientist machine learning data science c...  15-1111.00
# 33   business intelligence analyst data science dat...  15-1199.08
# 38   human resources data scientist machine learnin...  15-1111.00
# 57   lead human resource data scientist machine lea...  15-1111.00
# 76   machine learning engineer machine learning dat...  15-1111.00
# 95   data scientist machine learning data science y...  15-1111.00
# 114  associate data scientist machine learning data...  15-1111.00
# 133                    data scientist machine learning  15-1111.00
# 152  data scientist ai@unity machine learning data ...  15-1111.00
# 171  data scientist machine learning experience wor...  15-1111.00
#
#                                       titles_processed  score_all
# 0    [artificial intelligence specialist ai special...   0.883895
# 33   [analytical data miner, business analyst, busi...   0.866399
# 38   [artificial intelligence specialist ai special...   0.737225
# 57   [artificial intelligence specialist ai special...   0.738833
# 76   [artificial intelligence specialist ai special...   0.847708
# 95   [artificial intelligence specialist ai special...   0.846623
# 114  [artificial intelligence specialist ai special...   0.872069
# 133  [artificial intelligence specialist ai special...   0.884682
# 152  [artificial intelligence specialist ai special...   0.876431
# 171  [artificial intelligence specialist ai special...   0.847733

# %%
df1 = score_df.drop(['titles_processed', 'title_processed'], axis=1)
df2 = onet_oc_df[['identifier', 'name']].drop_duplicates()

get_occupation = df1.merge(df2, on='identifier', how='left')
get_occupation.head(5)
# Out:
#    id                                 title  identifier  score_all  \
# 0   1                        Data Scientist  15-1111.00   0.883895
# 1   2         Business Intelligence Analyst  15-1199.08   0.866399
# 2   3        Human Resources Data Scientist  15-1111.00   0.737225
# 3   4  Lead - Human Resource Data Scientist  15-1111.00   0.738833
# 4   5             Machine Learning Engineer  15-1111.00   0.847708
#
#                                            name
# 0  Computer and Information Research Scientists
# 1                Business Intelligence Analysts
# 2  Computer and Information Research Scientists
# 3  Computer and Information Research Scientists
# 4  Computer and Information Research Scientists

# %%
get_occupation[~get_occupation['title'].str.contains('data scientist', case=False, regex=False)].head(50)
# Out:
#       id                                              title  identifier  \
# 1      2                      Business Intelligence Analyst  15-1199.08
# 4      5                          Machine Learning Engineer  15-1111.00
# 12    13                         Jr. Data Science Developer  15-1111.00
# 17    18        Manager of Data Science, RACE21 - Vancouver  15-1111.00
# 19    20                        Lead Educator, Data Science  15-1111.00
# 20    21                         Jr. Data Science Developer  15-1111.00
# 23    24                                  Applied Scientist  15-1111.00
# 25    26                             Mine Planning Engineer  15-1199.02
# 26    27                      Human Resources Administrator  15-1141.00
# 27    28         Associate Director, Engineering Admissions  19-4061.00
# 28    29                    Data Center Operations Engineer  15-1121.00
# 29    30                          Software Engineer Level 3  15-1133.00
# 32    33                     Big Data Operations Specialist  15-1121.00
# 34    35                 Director, Data Science Initiatives  15-1111.00
# 36    47                      Business Intelligence Analyst  15-1199.08
# 45    56                         Jr. Data Science Developer  15-1111.00
# 51    62        Manager of Data Science, RACE21 - Vancouver  15-1111.00
# 53    64                        Lead Educator, Data Science  15-1111.00
# 54    65                         Jr. Data Science Developer  15-1111.00
# 57    68                                  Applied Scientist  15-1111.00
# 60    71                Data Architect (Advanced Analytics)  15-1199.06
# 62    73                      Business Intelligence Analyst  15-1199.08
# 64    75                      Business Intelligence Analyst  15-1199.08
# 65    76                          Machine Learning Engineer  15-1111.00
# 66    77   Machine learning / image processing - Apr to Sep  15-1111.00
# 70    81                      Machine Learning Geoscientist  15-1111.00
# 71    82                                Senior Data Analyst  15-1199.08
# 72    83                        Sr Data Analyst, UFC Mobile  15-1199.04
# 74    85                                Senior Data Analyst  13-2099.01
# 75    86           Artificial Intelligence/Machine Learning  15-1111.00
# 79    90        Manager of Data Science, RACE21 - Vancouver  15-1111.00
# 81    92        Manager of Data Science, RACE21 - Vancouver  15-1111.00
# 84    95           Machine Learning Engineer / Data Analyst  15-1111.00
# 85    96                                       NLP Engineer  15-1111.00
# 86    97                     Senior Enterprise Data Analyst  15-1199.08
# 87    98         Programmer Analyst II (Learning Analytics)  15-1121.00
# 88    99                           Senior Game Data Analyst  15-1199.07
# 89   100                                Senior Data Analyst  15-1121.00
# 90   101               Senior Renewable Energy Data Analyst  15-1121.00
# 91   102  Development Expert, SAP Analytics Cloud (Conve...  15-1121.00
# 92   103                      Business Intelligence Analyst  15-1199.08
# 95   106                          Sr. Manager, Data Science  15-1111.00
# 96   107                    Manager of Data Science, RACE21  15-1111.00
# 97   108  Applied Science Intern, Machine Learning (Canada)  15-1111.00
# 98   109                      Business Intelligence Analyst  15-1121.00
# 99   110                          Machine Learning Engineer  15-1111.00
# 100  111  Algorithm Developer (data science, C++, Java,N...  15-1141.00
# 101  112         Business Intelligence Developer (Contract)  15-1199.08
# 102  113       Senior Data Analyst, Cross Product Portfolio  15-1121.00
# 103  114       Senior Data Analyst, Cross Product Portfolio  15-1121.00
#
#      score_all                                               name
# 1     0.866399                     Business Intelligence Analysts
# 4     0.847708       Computer and Information Research Scientists
# 12    0.888068       Computer and Information Research Scientists
# 17    0.902421       Computer and Information Research Scientists
# 19    0.824635       Computer and Information Research Scientists
# 20    0.888068       Computer and Information Research Scientists
# 23    0.844633       Computer and Information Research Scientists
# 25    0.800736              Computer Systems Engineers/Architects
# 26    0.778960                            Database Administrators
# 27    0.840551                 Social Science Research Assistants
# 28    0.847657                          Computer Systems Analysts
# 29    0.860017              Software Developers, Systems Software
# 32    0.868237                          Computer Systems Analysts
# 34    0.865775       Computer and Information Research Scientists
# 36    0.866399                     Business Intelligence Analysts
# 45    0.888068       Computer and Information Research Scientists
# 51    0.902421       Computer and Information Research Scientists
# 53    0.824635       Computer and Information Research Scientists
# 54    0.888068       Computer and Information Research Scientists
# 57    0.844633       Computer and Information Research Scientists
# 60    0.876311                                Database Architects
# 62    0.866399                     Business Intelligence Analysts
# 64    0.866399                     Business Intelligence Analysts
# 65    0.847708       Computer and Information Research Scientists
# 66    0.642555       Computer and Information Research Scientists
# 70    0.854889       Computer and Information Research Scientists
# 71    0.877099                     Business Intelligence Analysts
# 72    0.829616  Geospatial Information Scientists and Technolo...
# 74    0.855339                    Financial Quantitative Analysts
# 75    0.812792       Computer and Information Research Scientists
# 79    0.902421       Computer and Information Research Scientists
# 81    0.902421       Computer and Information Research Scientists
# 84    0.862610       Computer and Information Research Scientists
# 85    0.766093       Computer and Information Research Scientists
# 86    0.862572                     Business Intelligence Analysts
# 87    0.903945                          Computer Systems Analysts
# 88    0.830173                       Data Warehousing Specialists
# 89    0.875314                          Computer Systems Analysts
# 90    0.877833                          Computer Systems Analysts
# 91    0.767495                          Computer Systems Analysts
# 92    0.866399                     Business Intelligence Analysts
# 95    0.825367       Computer and Information Research Scientists
# 96    0.901584       Computer and Information Research Scientists
# 97    0.825239       Computer and Information Research Scientists
# 98    0.870225                          Computer Systems Analysts
# 99    0.847708       Computer and Information Research Scientists
# 100   0.766236                            Database Administrators
# 101   0.817870                     Business Intelligence Analysts
# 102   0.896885                          Computer Systems Analysts
# 103   0.896885                          Computer Systems Analysts

# %%
# Save file
get_occupation.to_csv(home_path+'results/title_occupation.csv', index=False)
