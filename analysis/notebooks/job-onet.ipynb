# %%
import os
from skills_ml.storage import FSStore
from skills_ml.datasets.onet_cache import OnetSiteCache
from skills_ml.ontologies.onet import Onet
# Out:
# /Users/nguyencao/workspace/projects/data-catalysis/job-cruncher/.venv/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
file_store = FSStore(path=os.path.realpath('../../datasets/onet'))
onet_cache = OnetSiteCache(storage=file_store)
myonet = Onet(onet_cache=onet_cache)
myonet.print_summary_stats()
# Out:
# Ontology summary statistics for onet
# Num competencies: 47519
# Num occupations: 1133
# Num competency-occupation edges: 172438
# Median occupations per competency: 1.0
# Median competencies per occupation: 158
# Mean occupations per competency: 3.628898522665095
# Mean competencies per occupation: 152.19593998234774

# %%
computer_scientists = myonet.filter_by(lambda edge: 'Computer and Information Research Scientists' in edge.occupation.name)
computer_scientists.competencies
# Out:
# {Competency(identifier=1.A.1.a.1, name=Oral Comprehension, categories=['Abilities'], {'competencyText': 'The ability to listen to and understand information and ideas presented through spoken words and sentences.'}),
#  Competency(identifier=1.A.1.a.2, name=Written Comprehension, categories=['Abilities'], {'competencyText': 'The ability to read and understand information and ideas presented in writing.'}),
#  Competency(identifier=1.A.1.a.3, name=Oral Expression, categories=['Abilities'], {'competencyText': 'The ability to communicate information and ideas in speaking so others will understand.'}),
#  Competency(identifier=1.A.1.a.4, name=Written Expression, categories=['Abilities'], {'competencyText': 'The ability to communicate information and ideas in writing so others will understand.'}),
#  Competency(identifier=1.A.1.b.1, name=Fluency of Ideas, categories=['Abilities'], {'competencyText': 'The ability to come up with a number of ideas about a topic (the number of ideas is important, not their quality, correctness, or creativity).'}),
#  Competency(identifier=1.A.1.b.2, name=Originality, categories=['Abilities'], {'competencyText': 'The ability to come up with unusual or clever ideas about a given topic or situation, or to develop creative ways to solve a problem.'}),
#  Competency(identifier=1.A.1.b.3, name=Problem Sensitivity, categories=['Abilities'], {'competencyText': 'The ability to tell when something is wrong or is likely to go wrong. It does not involve solving the problem, only recognizing there is a problem.'}),
#  Competency(identifier=1.A.1.b.4, name=Deductive Reasoning, categories=['Abilities'], {'competencyText': 'The ability to apply general rules to specific problems to produce answers that make sense.'}),
#  Competency(identifier=1.A.1.b.5, name=Inductive Reasoning, categories=['Abilities'], {'competencyText': 'The ability to combine pieces of information to form general rules or conclusions (includes finding a relationship among seemingly unrelated events).'}),
#  Competency(identifier=1.A.1.b.6, name=Information Ordering, categories=['Abilities'], {'competencyText': 'The ability to arrange things or actions in a certain order or pattern according to a specific rule or set of rules (e.g., patterns of numbers, letters, words, pictures, mathematical operations).'}),
#  Competency(identifier=1.A.1.b.7, name=Category Flexibility, categories=['Abilities'], {'competencyText': 'The ability to generate or use different sets of rules for combining or grouping things in different ways.'}),
#  Competency(identifier=1.A.1.c.1, name=Mathematical Reasoning, categories=['Abilities'], {'competencyText': 'The ability to choose the right mathematical methods or formulas to solve a problem.'}),
#  Competency(identifier=1.A.1.c.2, name=Number Facility, categories=['Abilities'], {'competencyText': 'The ability to add, subtract, multiply, or divide quickly and correctly.'}),
#  Competency(identifier=1.A.1.e.2, name=Flexibility of Closure, categories=['Abilities'], {'competencyText': 'The ability to identify or detect a known pattern (a figure, object, word, or sound) that is hidden in other distracting material.'}),
#  Competency(identifier=1.A.1.e.3, name=Perceptual Speed, categories=['Abilities'], {'competencyText': 'The ability to quickly and accurately compare similarities and differences among sets of letters, numbers, objects, pictures, or patterns. The things to be compared may be presented at the same time or one after the other. This ability also includes comparing a presented object with a remembered object.'}),
#  Competency(identifier=1.A.1.f.2, name=Visualization, categories=['Abilities'], {'competencyText': 'The ability to imagine how something will look after it is moved around or when its parts are moved or rearranged.'}),
#  Competency(identifier=1.A.4.a.1, name=Near Vision, categories=['Abilities'], {'competencyText': 'The ability to see details at close range (within a few feet of the observer).'}),
#  Competency(identifier=1.A.4.b.4, name=Speech Recognition, categories=['Abilities'], {'competencyText': 'The ability to identify and understand the speech of another person.'}),
#  Competency(identifier=1.A.4.b.5, name=Speech Clarity, categories=['Abilities'], {'competencyText': 'The ability to speak clearly so others can understand you.'}),
#  Competency(identifier=1.B.2.a, name=Achievement, categories=['Work Values'], {'competencyText': 'Occupations that satisfy this work value are results oriented and allow employees to use their strongest abilities, giving them a feeling of accomplishment. Corresponding needs are Ability Utilization and Achievement.'}),
#  Competency(identifier=1.B.2.b, name=Working Conditions, categories=['Work Values'], {'competencyText': 'Occupations that satisfy this work value offer job security and good working conditions. Corresponding needs are Activity, Compensation, Independence, Security, Variety and Working Conditions.'}),
#  Competency(identifier=1.B.2.c, name=Recognition, categories=['Work Values'], {'competencyText': 'Occupations that satisfy this work value offer advancement, potential for leadership, and are often considered prestigious. Corresponding needs are Advancement, Authority, Recognition and Social Status.'}),
#  Competency(identifier=1.B.2.d, name=Relationships, categories=['Work Values'], {'competencyText': 'Occupations that satisfy this work value allow employees to provide service to others and work with co-workers in a friendly non-competitive environment. Corresponding needs are Co-workers, Moral Values and Social Service.'}),
#  Competency(identifier=1.B.2.e, name=Support, categories=['Work Values'], {'competencyText': 'Occupations that satisfy this work value offer supportive management that stands behind employees. Corresponding needs are Company Policies, Supervision: Human Relations and Supervision: Technical.'}),
#  Competency(identifier=1.B.2.f, name=Independence, categories=['Work Values'], {'competencyText': 'Occupations that satisfy this work value allow employees to work on their own and make decisions. Corresponding needs are Creativity, Responsibility and Autonomy.'}),
#  Competency(identifier=1.C.1.a, name=Achievement/Effort, categories=['Work Styles'], {'competencyText': 'Job requires establishing and maintaining personally challenging achievement goals and exerting effort toward mastering tasks.'}),
#  Competency(identifier=1.C.1.b, name=Persistence, categories=['Work Styles'], {'competencyText': 'Job requires persistence in the face of obstacles.'}),
#  Competency(identifier=1.C.1.c, name=Initiative, categories=['Work Styles'], {'competencyText': 'Job requires a willingness to take on responsibilities and challenges.'}),
#  Competency(identifier=1.C.2.b, name=Leadership, categories=['Work Styles'], {'competencyText': 'Job requires a willingness to lead, take charge, and offer opinions and direction.'}),
#  Competency(identifier=1.C.3.a, name=Cooperation, categories=['Work Styles'], {'competencyText': 'Job requires being pleasant with others on the job and displaying a good-natured, cooperative attitude.'}),
#  Competency(identifier=1.C.3.b, name=Concern for Others, categories=['Work Styles'], {'competencyText': "Job requires being sensitive to others' needs and feelings and being understanding and helpful on the job."}),
#  Competency(identifier=1.C.3.c, name=Social Orientation, categories=['Work Styles'], {'competencyText': 'Job requires preferring to work with others rather than alone, and being personally connected with others on the job.'}),
#  Competency(identifier=1.C.4.a, name=Self Control, categories=['Work Styles'], {'competencyText': 'Job requires maintaining composure, keeping emotions in check, controlling anger, and avoiding aggressive behavior, even in very difficult situations.'}),
#  Competency(identifier=1.C.4.b, name=Stress Tolerance, categories=['Work Styles'], {'competencyText': 'Job requires accepting criticism and dealing calmly and effectively with high stress situations.'}),
#  Competency(identifier=1.C.4.c, name=Adaptability/Flexibility, categories=['Work Styles'], {'competencyText': 'Job requires being open to change (positive or negative) and to considerable variety in the workplace.'}),
#  Competency(identifier=1.C.5.a, name=Dependability, categories=['Work Styles'], {'competencyText': 'Job requires being reliable, responsible, and dependable, and fulfilling obligations.'}),
#  Competency(identifier=1.C.5.b, name=Attention to Detail, categories=['Work Styles'], {'competencyText': 'Job requires being careful about detail and thorough in completing work tasks.'}),
#  Competency(identifier=1.C.5.c, name=Integrity, categories=['Work Styles'], {'competencyText': 'Job requires being honest and ethical.'}),
#  Competency(identifier=1.C.6, name=Independence, categories=['Work Styles'], {'competencyText': "Job requires developing one's own ways of doing things, guiding oneself with little or no supervision, and depending on oneself to get things done."}),
#  Competency(identifier=1.C.7.a, name=Innovation, categories=['Work Styles'], {'competencyText': 'Job requires creativity and alternative thinking to develop new ideas for and answers to work-related problems.'}),
#  Competency(identifier=1.C.7.b, name=Analytical Thinking, categories=['Work Styles'], {'competencyText': 'Job requires analyzing information and using logic to address work-related issues and problems.'}),
#  Competency(identifier=14623, name=Analyze problems to develop solutions involving computer hardware and software., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14624, name=Assign or schedule tasks to meet work priorities and goals., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14625, name=Evaluate project plans and proposals to assess feasibility issues., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14626, name=Apply theoretical expertise and innovation to create or apply new technology, such as adapting principles for applying computers to new uses., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14627, name=Consult with users, management, vendors, and technicians to determine computing needs and system requirements., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14628, name=Meet with managers, vendors, and others to solicit cooperation and resolve problems., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14629, name=Conduct logical analyses of business, scientific, engineering, and other technical problems, formulating mathematical models of problems for solution by computers., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14630, name=Develop and interpret organizational goals, policies, and procedures., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14631, name=Participate in staffing decisions and direct training of subordinates., categories=['Task Statements'], {'competencyText': 'Supplemental'}),
#  Competency(identifier=14632, name=Develop performance standards, and evaluate work in light of established standards., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14633, name=Design computers and the software that runs them., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14634, name=Maintain network hardware and software, direct network security measures, and monitor networks to ensure availability to system users., categories=['Task Statements'], {'competencyText': 'Supplemental'}),
#  Competency(identifier=14635, name=Participate in multidisciplinary projects in areas such as virtual reality, human-computer interaction, or robotics., categories=['Task Statements'], {'competencyText': 'Core'}),
#  Competency(identifier=14636, name=Approve, prepare, monitor, and adjust operational budgets., categories=['Task Statements'], {'competencyText': 'Supplemental'}),
#  Competency(identifier=14637, name=Direct daily operations of departments, coordinating project activities with other departments., categories=['Task Statements'], {'competencyText': 'Supplemental'}),
#  Competency(identifier=2.A.1.a, name=Reading Comprehension, categories=['Skills'], {'competencyText': 'Understanding written sentences and paragraphs in work related documents.'}),
#  Competency(identifier=2.A.1.b, name=Active Listening, categories=['Skills'], {'competencyText': 'Giving full attention to what other people are saying, taking time to understand the points being made, asking questions as appropriate, and not interrupting at inappropriate times.'}),
#  Competency(identifier=2.A.1.c, name=Writing, categories=['Skills'], {'competencyText': 'Communicating effectively in writing as appropriate for the needs of the audience.'}),
#  Competency(identifier=2.A.1.d, name=Speaking, categories=['Skills'], {'competencyText': 'Talking to others to convey information effectively.'}),
#  Competency(identifier=2.A.1.e, name=Mathematics, categories=['Skills'], {'competencyText': 'Using mathematics to solve problems.'}),
#  Competency(identifier=2.A.1.f, name=Science, categories=['Skills'], {'competencyText': 'Using scientific rules and methods to solve problems.'}),
#  Competency(identifier=2.A.2.a, name=Critical Thinking, categories=['Skills'], {'competencyText': 'Using logic and reasoning to identify the strengths and weaknesses of alternative solutions, conclusions or approaches to problems.'}),
#  Competency(identifier=2.A.2.b, name=Active Learning, categories=['Skills'], {'competencyText': 'Understanding the implications of new information for both current and future problem-solving and decision-making.'}),
#  Competency(identifier=2.A.2.c, name=Learning Strategies, categories=['Skills'], {'competencyText': 'Selecting and using training/instructional methods and procedures appropriate for the situation when learning or teaching new things.'}),
#  Competency(identifier=2.A.2.d, name=Monitoring, categories=['Skills'], {'competencyText': 'Monitoring/Assessing performance of yourself, other individuals, or organizations to make improvements or take corrective action.'}),
#  Competency(identifier=2.B.1.a, name=Social Perceptiveness, categories=['Skills'], {'competencyText': "Being aware of others' reactions and understanding why they react as they do."}),
#  Competency(identifier=2.B.1.b, name=Coordination, categories=['Skills'], {'competencyText': "Adjusting actions in relation to others' actions."}),
#  Competency(identifier=2.B.1.e, name=Instructing, categories=['Skills'], {'competencyText': 'Teaching others how to do something.'}),
#  Competency(identifier=2.B.2.i, name=Complex Problem Solving, categories=['Skills'], {'competencyText': 'Identifying complex problems and reviewing related information to develop and evaluate options and implement solutions.'}),
#  Competency(identifier=2.B.3.a, name=Operations Analysis, categories=['Skills'], {'competencyText': 'Analyzing needs and product requirements to create a design.'}),
#  Competency(identifier=2.B.3.b, name=Technology Design, categories=['Skills'], {'competencyText': 'Generating or adapting equipment and technology to serve user needs.'}),
#  Competency(identifier=2.B.3.e, name=Programming, categories=['Skills'], {'competencyText': 'Writing computer programs for various purposes.'}),
#  Competency(identifier=2.B.4.e, name=Judgment and Decision Making, categories=['Skills'], {'competencyText': 'Considering the relative costs and benefits of potential actions to choose the most appropriate one.'}),
#  Competency(identifier=2.B.4.g, name=Systems Analysis, categories=['Skills'], {'competencyText': 'Determining how a system should work and how changes in conditions, operations, and the environment will affect outcomes.'}),
#  Competency(identifier=2.B.4.h, name=Systems Evaluation, categories=['Skills'], {'competencyText': 'Identifying measures or indicators of system performance and the actions needed to improve or correct performance, relative to the goals of the system.'}),
#  Competency(identifier=2.B.5.a, name=Time Management, categories=['Skills'], {'competencyText': "Managing one's own time and the time of others."}),
#  Competency(identifier=2.C.1.a, name=Administration and Management, categories=['Knowledge'], {'competencyText': 'Knowledge of business and management principles involved in strategic planning, resource allocation, human resources modeling, leadership technique, production methods, and coordination of people and resources.'}),
#  Competency(identifier=2.C.3.a, name=Computers and Electronics, categories=['Knowledge'], {'competencyText': 'Knowledge of circuit boards, processors, chips, electronic equipment, and computer hardware and software, including applications and programming.'}),
#  Competency(identifier=2.C.3.b, name=Engineering and Technology, categories=['Knowledge'], {'competencyText': 'Knowledge of the practical application of engineering science and technology. This includes applying principles, techniques, procedures, and equipment to the design and production of various goods and services.'}),
#  Competency(identifier=2.C.3.c, name=Design, categories=['Knowledge'], {'competencyText': 'Knowledge of design techniques, tools, and principles involved in production of precision technical plans, blueprints, drawings, and models.'}),
#  Competency(identifier=2.C.4.a, name=Mathematics, categories=['Knowledge'], {'competencyText': 'Knowledge of arithmetic, algebra, geometry, calculus, statistics, and their applications.'}),
#  Competency(identifier=2.C.7.a, name=English Language, categories=['Knowledge'], {'competencyText': 'Knowledge of the structure and content of the English language including the meaning and spelling of words, rules of composition, and grammar.'}),
#  Competency(identifier=2.C.9.a, name=Telecommunications, categories=['Knowledge'], {'competencyText': 'Knowledge of transmission, broadcasting, switching, control, and operation of telecommunications systems.'}),
#  Competency(identifier=23153202-Articulated robots, name=Articulated robots, categories=['Tools Used'], {'competencyText': 'Pick or place robots'}),
#  Competency(identifier=23153202-Mobile robots, name=Mobile robots, categories=['Tools Used'], {'competencyText': 'Pick or place robots'}),
#  Competency(identifier=32101626-Microcomputers, name=Microcomputers, categories=['Tools Used'], {'competencyText': 'Microprocessors'}),
#  Competency(identifier=39111504-Lighting grids, name=Lighting grids, categories=['Tools Used'], {'competencyText': 'Stage or projection or studio lighting system'}),
#  Competency(identifier=4.A.1.a.1, name=Getting Information, categories=['Work Activities'], {'competencyText': 'Observing, receiving, and otherwise obtaining information from all relevant sources.'}),
#  Competency(identifier=4.A.1.a.2, name=Monitor Processes, Materials, or Surroundings, categories=['Work Activities'], {'competencyText': 'Monitoring and reviewing information from materials, events, or the environment, to detect or assess problems.'}),
#  Competency(identifier=4.A.1.b.1, name=Identifying Objects, Actions, and Events, categories=['Work Activities'], {'competencyText': 'Identifying information by categorizing, estimating, recognizing differences or similarities, and detecting changes in circumstances or events.'}),
#  Competency(identifier=4.A.1.b.3, name=Estimating the Quantifiable Characteristics of Products, Events, or Information, categories=['Work Activities'], {'competencyText': 'Estimating sizes, distances, and quantities; or determining time, costs, resources, or materials needed to perform a work activity.'}),
#  Competency(identifier=4.A.2.a.1, name=Judging the Qualities of Things, Services, or People, categories=['Work Activities'], {'competencyText': 'Assessing the value, importance, or quality of things or people.'}),
#  Competency(identifier=4.A.2.a.2, name=Processing Information, categories=['Work Activities'], {'competencyText': 'Compiling, coding, categorizing, calculating, tabulating, auditing, or verifying information or data.'}),
#  Competency(identifier=4.A.2.a.3, name=Evaluating Information to Determine Compliance with Standards, categories=['Work Activities'], {'competencyText': 'Using relevant information and individual judgment to determine whether events or processes comply with laws, regulations, or standards.'}),
#  Competency(identifier=4.A.2.a.4, name=Analyzing Data or Information, categories=['Work Activities'], {'competencyText': 'Identifying the underlying principles, reasons, or facts of information by breaking down information or data into separate parts.'}),
#  Competency(identifier=4.A.2.b.1, name=Making Decisions and Solving Problems, categories=['Work Activities'], {'competencyText': 'Analyzing information and evaluating results to choose the best solution and solve problems.'}),
#  Competency(identifier=4.A.2.b.2, name=Thinking Creatively, categories=['Work Activities'], {'competencyText': 'Developing, designing, or creating new applications, ideas, relationships, systems, or products, including artistic contributions.'}),
#  Competency(identifier=4.A.2.b.3, name=Updating and Using Relevant Knowledge, categories=['Work Activities'], {'competencyText': 'Keeping up-to-date technically and applying new knowledge to your job.'}),
#  Competency(identifier=4.A.2.b.4, name=Developing Objectives and Strategies, categories=['Work Activities'], {'competencyText': 'Establishing long-range objectives and specifying the strategies and actions to achieve them.'}),
#  Competency(identifier=4.A.2.b.5, name=Scheduling Work and Activities, categories=['Work Activities'], {'competencyText': 'Scheduling events, programs, and activities, as well as the work of others.'}),
#  Competency(identifier=4.A.2.b.6, name=Organizing, Planning, and Prioritizing Work, categories=['Work Activities'], {'competencyText': 'Developing specific goals and plans to prioritize, organize, and accomplish your work.'}),
#  Competency(identifier=4.A.3.b.1, name=Interacting With Computers, categories=['Work Activities'], {'competencyText': 'Using computers and computer systems (including hardware and software) to program, write software, set up functions, enter data, or process information.'}),
#  Competency(identifier=4.A.3.b.6, name=Documenting/Recording Information, categories=['Work Activities'], {'competencyText': 'Entering, transcribing, recording, storing, or maintaining information in written or electronic/magnetic form.'}),
#  Competency(identifier=4.A.4.a.1, name=Interpreting the Meaning of Information for Others, categories=['Work Activities'], {'competencyText': 'Translating or explaining what information means and how it can be used.'}),
#  Competency(identifier=4.A.4.a.2, name=Communicating with Supervisors, Peers, or Subordinates, categories=['Work Activities'], {'competencyText': 'Providing information to supervisors, co-workers, and subordinates by telephone, in written form, e-mail, or in person.'}),
#  Competency(identifier=4.A.4.a.3, name=Communicating with Persons Outside Organization, categories=['Work Activities'], {'competencyText': 'Communicating with people outside the organization, representing the organization to customers, the public, government, and other external sources. This information can be exchanged in person, in writing, or by telephone or e-mail.'}),
#  Competency(identifier=4.A.4.a.4, name=Establishing and Maintaining Interpersonal Relationships, categories=['Work Activities'], {'competencyText': 'Developing constructive and cooperative working relationships with others, and maintaining them over time.'}),
#  Competency(identifier=4.A.4.b.3, name=Training and Teaching Others, categories=['Work Activities'], {'competencyText': 'Identifying the educational needs of others, developing formal educational or training programs or classes, and teaching or instructing others.'}),
#  Competency(identifier=4.A.4.b.6, name=Provide Consultation and Advice to Others, categories=['Work Activities'], {'competencyText': 'Providing guidance and expert advice to management or other groups on technical, systems-, or process-related topics.'}),
#  Competency(identifier=43201404-Network interface cards NIC, name=Network interface cards NIC, categories=['Tools Used'], {'competencyText': 'Network interface cards'}),
#  Competency(identifier=43201802-Network storage arrays, name=Network storage arrays, categories=['Tools Used'], {'competencyText': 'Hard disk arrays'}),
#  Competency(identifier=43201803-Hard disk drives, name=Hard disk drives, categories=['Tools Used'], {'competencyText': 'Hard disk drives'}),
#  Competency(identifier=43201806-Quarter inch cartridge QIC tapes, name=Quarter inch cartridge QIC tapes, categories=['Tools Used'], {'competencyText': 'Tape arrays'}),
#  Competency(identifier=43201813-Universal serial bus USB flash drives, name=Universal serial bus USB flash drives, categories=['Tools Used'], {'competencyText': 'High capacity removable media drives'}),
#  Competency(identifier=43202001-Magneto optical discs, name=Magneto optical discs, categories=['Tools Used'], {'competencyText': 'Compact disks CDs'}),
#  Competency(identifier=43211501-File servers, name=File servers, categories=['Tools Used'], {'competencyText': 'Computer servers'}),
#  Competency(identifier=43211501-Web servers, name=Web servers, categories=['Tools Used'], {'competencyText': 'Computer servers'}),
#  Competency(identifier=43211502-Cluster systems, name=Cluster systems, categories=['Tools Used'], {'competencyText': 'High end computer servers'}),
#  Competency(identifier=43211502-Distributed heterogeneous computers, name=Distributed heterogeneous computers, categories=['Tools Used'], {'competencyText': 'High end computer servers'}),
#  Competency(identifier=43211502-High end computer servers, name=High end computer servers, categories=['Tools Used'], {'competencyText': 'High end computer servers'}),
#  Competency(identifier=43211502-High-performance cluster HPC computers, name=High-performance cluster HPC computers, categories=['Tools Used'], {'competencyText': 'High end computer servers'}),
#  Competency(identifier=43211502-Massively parallel processors MPP, name=Massively parallel processors MPP, categories=['Tools Used'], {'competencyText': 'High end computer servers'}),
#  Competency(identifier=43211502-Render farms, name=Render farms, categories=['Tools Used'], {'competencyText': 'High end computer servers'}),
#  Competency(identifier=43211508-Personal computers, name=Personal computers, categories=['Tools Used'], {'competencyText': 'Personal computers'}),
#  Competency(identifier=43211512-Mainframe computers, name=Mainframe computers, categories=['Tools Used'], {'competencyText': 'Mainframe computers'}),
#  Competency(identifier=43211711-Computer scanners, name=Computer scanners, categories=['Tools Used'], {'competencyText': 'Scanners'}),
#  Competency(identifier=43211711-Laser scanners, name=Laser scanners, categories=['Tools Used'], {'competencyText': 'Scanners'}),
#  Competency(identifier=43211712-Graphics workstations, name=Graphics workstations, categories=['Tools Used'], {'competencyText': 'Graphics tablets'}),
#  Competency(identifier=43211718-Image capture devices, name=Image capture devices, categories=['Tools Used'], {'competencyText': 'Camera based vision systems for automated data collection'}),
#  Competency(identifier=43211718-Real time motion capture systems, name=Real time motion capture systems, categories=['Tools Used'], {'competencyText': 'Camera based vision systems for automated data collection'}),
#  Competency(identifier=43212105-Computer laser printers, name=Computer laser printers, categories=['Tools Used'], {'competencyText': 'Laser printers'}),
#  Competency(identifier=43222604-High-speed networking testbeds, name=High-speed networking testbeds, categories=['Tools Used'], {'competencyText': 'Content delivery networking equipment'}),
#  Competency(identifier=43231507-Microsoft Project, name=Microsoft Project, categories=['Technology Skills'], {'competencyText': 'Project management software'}),
#  Competency(identifier=43231513-Microsoft Office, name=Microsoft Office, categories=['Technology Skills'], {'competencyText': 'Office suite software'}),
#  Competency(identifier=43231514-Google AdWords, name=Google AdWords, categories=['Technology Skills'], {'competencyText': 'Sales and marketing software'}),
#  Competency(identifier=43231602-SAP Business Objects, name=SAP Business Objects, categories=['Technology Skills'], {'competencyText': 'Enterprise resource planning ERP software'}),
#  Competency(identifier=43232102-Graphics pipelines, name=Graphics pipelines, categories=['Technology Skills'], {'competencyText': 'Graphics or photo imaging software'}),
#  Competency(identifier=43232102-Open Graphics Library OpenGL, name=Open Graphics Library OpenGL, categories=['Technology Skills'], {'competencyText': 'Graphics or photo imaging software'}),
#  Competency(identifier=43232102-Three-dimensional 3D graphics software, name=Three-dimensional 3D graphics software, categories=['Technology Skills'], {'competencyText': 'Graphics or photo imaging software'}),
#  Competency(identifier=43232103-Video editing software, name=Video editing software, categories=['Technology Skills'], {'competencyText': 'Video creation and editing software'}),
#  Competency(identifier=43232106-Microsoft PowerPoint, name=Microsoft PowerPoint, categories=['Technology Skills'], {'competencyText': 'Presentation software'}),
#  Competency(identifier=43232107-Plug-in file software, name=Plug-in file software, categories=['Technology Skills'], {'competencyText': 'Web page creation and editing software'}),
#  Competency(identifier=43232110-Microsoft Excel, name=Microsoft Excel, categories=['Technology Skills'], {'competencyText': 'Spreadsheet software'}),
#  Competency(identifier=43232203-Git, name=Git, categories=['Technology Skills'], {'competencyText': 'File versioning software'}),
#  Competency(identifier=43232302-Clustering software, name=Clustering software, categories=['Technology Skills'], {'competencyText': 'Clustering software'}),
#  Competency(identifier=43232302-Clustermatic, name=Clustermatic, categories=['Technology Skills'], {'competencyText': 'Clustering software'}),
#  Competency(identifier=43232302-Parallel systems software, name=Parallel systems software, categories=['Technology Skills'], {'competencyText': 'Clustering software'}),
#  Competency(identifier=43232304-Apache Cassandra, name=Apache Cassandra, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Apache Flume, name=Apache Flume, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Apache Hadoop, name=Apache Hadoop, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Apache Pig, name=Apache Pig, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Apache Solr, name=Apache Solr, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Elasticsearch, name=Elasticsearch, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-MongoDB, name=MongoDB, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-MySQL, name=MySQL, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-NoSQL, name=NoSQL, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Oracle DBMS, name=Oracle DBMS, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Relational database management software, name=Relational database management software, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Relational database management system software, name=Relational database management system software, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232304-Teradata Database, name=Teradata Database, categories=['Technology Skills'], {'competencyText': 'Data base management system software'}),
#  Competency(identifier=43232306-Amazon Redshift, name=Amazon Redshift, categories=['Technology Skills'], {'competencyText': 'Data base user interface and query software'}),
#  Competency(identifier=43232306-Apache Hive, name=Apache Hive, categories=['Technology Skills'], {'competencyText': 'Data base user interface and query software'}),
#  Competency(identifier=43232306-Data entry software, name=Data entry software, categories=['Technology Skills'], {'competencyText': 'Data base user interface and query software'}),
#  Competency(identifier=43232306-Microsoft SQL Server, name=Microsoft SQL Server, categories=['Technology Skills'], {'competencyText': 'Data base user interface and query software'}),
#  Competency(identifier=43232306-Structured query language SQL, name=Structured query language SQL, categories=['Technology Skills'], {'competencyText': 'Data base user interface and query software'}),
#  Competency(identifier=43232307-Data mining software, name=Data mining software, categories=['Technology Skills'], {'competencyText': 'Data mining software'}),
#  Competency(identifier=43232307-Google Analytics, name=Google Analytics, categories=['Technology Skills'], {'competencyText': 'Data mining software'}),
#  Competency(identifier=43232310-CA Erwin Data Modeler, name=CA Erwin Data Modeler, categories=['Technology Skills'], {'competencyText': 'Metadata management software'}),
#  Competency(identifier=43232311-PostgreSQL, name=PostgreSQL, categories=['Technology Skills'], {'competencyText': 'Object oriented data base management software'}),
#  Competency(identifier=43232312-Apache HTTP Server, name=Apache HTTP Server, categories=['Technology Skills'], {'competencyText': 'Portal server software'}),
#  Competency(identifier=43232314-IBM Cognos Impromptu, name=IBM Cognos Impromptu, categories=['Technology Skills'], {'competencyText': 'Business intelligence and data analysis software'}),
#  Competency(identifier=43232314-MicroStrategy, name=MicroStrategy, categories=['Technology Skills'], {'competencyText': 'Business intelligence and data analysis software'}),
#  Competency(identifier=43232314-Oracle Business Intelligence Enterprise Edition, name=Oracle Business Intelligence Enterprise Edition, categories=['Technology Skills'], {'competencyText': 'Business intelligence and data analysis software'}),
#  Competency(identifier=43232314-Qlik Tech QlikView, name=Qlik Tech QlikView, categories=['Technology Skills'], {'competencyText': 'Business intelligence and data analysis software'}),
#  Competency(identifier=43232314-Tableau, name=Tableau, categories=['Technology Skills'], {'competencyText': 'Business intelligence and data analysis software'}),
#  Competency(identifier=43232401-IBM Rational Apex, name=IBM Rational Apex, categories=['Technology Skills'], {'competencyText': 'Configuration management software'}),
#  Competency(identifier=43232401-Perforce Software Configuration Management System, name=Perforce Software Configuration Management System, categories=['Technology Skills'], {'competencyText': 'Configuration management software'}),
#  Competency(identifier=43232402-Ada, name=Ada, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Apache Kafka, name=Apache Kafka, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Automated document generation software, name=Automated document generation software, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-C, name=C, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-CMAKE, name=CMAKE, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Doxygen, name=Doxygen, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Eclipse IDE, name=Eclipse IDE, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Embarcadero JBuilder, name=Embarcadero JBuilder, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Formula translation/translator FORTRAN, name=Formula translation/translator FORTRAN, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-High-performance software libraries, name=High-performance software libraries, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-IBM Rational Rose, name=IBM Rational Rose, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Integrated development environment IDE software, name=Integrated development environment IDE software, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Intel Integrated Performance Primitives, name=Intel Integrated Performance Primitives, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-List processing language LISP, name=List processing language LISP, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Microsoft Azure, name=Microsoft Azure, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Microsoft Visual Basic, name=Microsoft Visual Basic, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Microsoft Visual Studio, name=Microsoft Visual Studio, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Microsoft Visual Studio.NET, name=Microsoft Visual Studio.NET, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-National Instruments LabVIEW, name=National Instruments LabVIEW, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Prolog, name=Prolog, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Ruby, name=Ruby, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Software libraries, name=Software libraries, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Source code management SCM software, name=Source code management SCM software, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Sun Microsystems Java 2 Platform Enterprise Edition J2EE, name=Sun Microsystems Java 2 Platform Enterprise Edition J2EE, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232402-Verilog, name=Verilog, categories=['Technology Skills'], {'competencyText': 'Development environment software'}),
#  Competency(identifier=43232403-Extensible markup language XML, name=Extensible markup language XML, categories=['Technology Skills'], {'competencyText': 'Enterprise application integration software'}),
#  Competency(identifier=43232403-IBM InfoSphere DataStage, name=IBM InfoSphere DataStage, categories=['Technology Skills'], {'competencyText': 'Enterprise application integration software'}),
#  Competency(identifier=43232404-Waikato Environment for Knowledge Analysis Weka, name=Waikato Environment for Knowledge Analysis Weka, categories=['Technology Skills'], {'competencyText': 'Graphical user interface development software'}),
#  Competency(identifier=43232405-C#, name=C#, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-C++, name=C++, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Charm++, name=Charm++, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Eiffel, name=Eiffel, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Jupyter Notebook, name=Jupyter Notebook, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Microsoft ActiveX, name=Microsoft ActiveX, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Microsoft Visual Basic.NET, name=Microsoft Visual Basic.NET, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Microsoft Visual C# .NET, name=Microsoft Visual C# .NET, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Object oriented development environment software, name=Object oriented development environment software, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Oracle Java, name=Oracle Java, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Practical extraction and reporting language Perl, name=Practical extraction and reporting language Perl, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Python, name=Python, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-R, name=R, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232405-Scala, name=Scala, categories=['Technology Skills'], {'competencyText': 'Object or component oriented development software'}),
#  Competency(identifier=43232407-Unified modeling language UML, name=Unified modeling language UML, categories=['Technology Skills'], {'competencyText': 'Requirements analysis and system architecture software'}),
#  Competency(identifier=43232408-Django, name=Django, categories=['Technology Skills'], {'competencyText': 'Web platform development software'}),
#  Competency(identifier=43232408-Extensible stylesheet language transformations XSLT, name=Extensible stylesheet language transformations XSLT, categories=['Technology Skills'], {'competencyText': 'Web platform development software'}),
#  Competency(identifier=43232408-JavaScript, name=JavaScript, categories=['Technology Skills'], {'competencyText': 'Web platform development software'}),
#  Competency(identifier=43232408-PHP: Hypertext Preprocessor, name=PHP: Hypertext Preprocessor, categories=['Technology Skills'], {'competencyText': 'Web platform development software'}),
#  Competency(identifier=43232409-Greenhills Ada compilers, name=Greenhills Ada compilers, categories=['Technology Skills'], {'competencyText': 'Compiler and decompiler software'}),
#  Competency(identifier=43232409-Low-level virtual machine LLVM compilers, name=Low-level virtual machine LLVM compilers, categories=['Technology Skills'], {'competencyText': 'Compiler and decompiler software'}),
#  Competency(identifier=43232409-Polaris parallelizing compilers, name=Polaris parallelizing compilers, categories=['Technology Skills'], {'competencyText': 'Compiler and decompiler software'}),
#  Competency(identifier=43232604-Computer aided design and drafting CADD software, name=Computer aided design and drafting CADD software, categories=['Technology Skills'], {'competencyText': 'Computer aided design CAD software'}),
#  Competency(identifier=43232604-PTC Creo Parametric, name=PTC Creo Parametric, categories=['Technology Skills'], {'competencyText': 'Computer aided design CAD software'}),
#  Competency(identifier=43232605-Advanced numerical software, name=Advanced numerical software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Algorithmic software, name=Algorithmic software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Augmint, name=Augmint, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Computational statistics software, name=Computational statistics software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Data visualization software, name=Data visualization software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-IBM SPSS Statistics, name=IBM SPSS Statistics, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Intel Math Kernel Library, name=Intel Math Kernel Library, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Mathematical software, name=Mathematical software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Minitab, name=Minitab, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Multisensory data representation software, name=Multisensory data representation software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Optimization software, name=Optimization software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Polhemus Fasttrack System, name=Polhemus Fasttrack System, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Rice Simulator for ILP Multiprocessors RSIM, name=Rice Simulator for ILP Multiprocessors RSIM, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-SAS, name=SAS, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-Simulation software, name=Simulation software, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-StataCorp Stata, name=StataCorp Stata, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232605-The MathWorks MATLAB, name=The MathWorks MATLAB, categories=['Technology Skills'], {'competencyText': 'Analytical or scientific software'}),
#  Competency(identifier=43232701-GitHub, name=GitHub, categories=['Technology Skills'], {'competencyText': 'Application server software'}),
#  Competency(identifier=43232902-IBM Domino, name=IBM Domino, categories=['Technology Skills'], {'competencyText': 'Communications server software'}),
#  Competency(identifier=43233004-Bash, name=Bash, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-Linux, name=Linux, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-Microsoft Windows XP, name=Microsoft Windows XP, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-Oracle Solaris, name=Oracle Solaris, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-Shell script, name=Shell script, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-Sun Microsystems Solaris, name=Sun Microsystems Solaris, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-UNIX, name=UNIX, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-Ubuntu, name=Ubuntu, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233004-VME PowerPC VxWorks, name=VME PowerPC VxWorks, categories=['Technology Skills'], {'competencyText': 'Operating system software'}),
#  Competency(identifier=43233506-ESRI ArcGIS software, name=ESRI ArcGIS software, categories=['Technology Skills'], {'competencyText': 'Map creation software'}),
#  Competency(identifier=43233506-Geographic information system GIS software, name=Geographic information system GIS software, categories=['Technology Skills'], {'competencyText': 'Map creation software'}),
#  Competency(identifier=43233701-Splunk Enterprise, name=Splunk Enterprise, categories=['Technology Skills'], {'competencyText': 'Enterprise system management software'}),
#  Competency(identifier=45111609-Stereographic projectors, name=Stereographic projectors, categories=['Tools Used'], {'competencyText': 'Multimedia projectors'}),
#  Competency(identifier=45111609-Video projectors, name=Video projectors, categories=['Tools Used'], {'competencyText': 'Multimedia projectors'}),
#  Competency(identifier=45121504-Digital cameras, name=Digital cameras, categories=['Tools Used'], {'competencyText': 'Digital cameras'}),
#  Competency(identifier=45121505-Pan-tilt-zoom cameras, name=Pan-tilt-zoom cameras, categories=['Tools Used'], {'competencyText': 'Cinematographic cameras'}),
#  Competency(identifier=45121516-Digital video cameras, name=Digital video cameras, categories=['Tools Used'], {'competencyText': 'Digital camcorders or video cameras'}),
#  Competency(identifier=52161512-Free-field speakers, name=Free-field speakers, categories=['Tools Used'], {'competencyText': 'Loudspeakers'})}

# %%
[(competency.name,competency.other_attributes['competencyText']) for competency in computer_scientists.competencies if competency.categories[0] == 'Abilities']
# Out:
# [('Visualization',
#   'The ability to imagine how something will look after it is moved around or when its parts are moved or rearranged.'),
#  ('Mathematical Reasoning',
#   'The ability to choose the right mathematical methods or formulas to solve a problem.'),
#  ('Speech Recognition',
#   'The ability to identify and understand the speech of another person.'),
#  ('Perceptual Speed',
#   'The ability to quickly and accurately compare similarities and differences among sets of letters, numbers, objects, pictures, or patterns. The things to be compared may be presented at the same time or one after the other. This ability also includes comparing a presented object with a remembered object.'),
#  ('Written Comprehension',
#   'The ability to read and understand information and ideas presented in writing.'),
#  ('Oral Comprehension',
#   'The ability to listen to and understand information and ideas presented through spoken words and sentences.'),
#  ('Speech Clarity',
#   'The ability to speak clearly so others can understand you.'),
#  ('Flexibility of Closure',
#   'The ability to identify or detect a known pattern (a figure, object, word, or sound) that is hidden in other distracting material.'),
#  ('Near Vision',
#   'The ability to see details at close range (within a few feet of the observer).'),
#  ('Category Flexibility',
#   'The ability to generate or use different sets of rules for combining or grouping things in different ways.'),
#  ('Deductive Reasoning',
#   'The ability to apply general rules to specific problems to produce answers that make sense.'),
#  ('Problem Sensitivity',
#   'The ability to tell when something is wrong or is likely to go wrong. It does not involve solving the problem, only recognizing there is a problem.'),
#  ('Fluency of Ideas',
#   'The ability to come up with a number of ideas about a topic (the number of ideas is important, not their quality, correctness, or creativity).'),
#  ('Oral Expression',
#   'The ability to communicate information and ideas in speaking so others will understand.'),
#  ('Information Ordering',
#   'The ability to arrange things or actions in a certain order or pattern according to a specific rule or set of rules (e.g., patterns of numbers, letters, words, pictures, mathematical operations).'),
#  ('Inductive Reasoning',
#   'The ability to combine pieces of information to form general rules or conclusions (includes finding a relationship among seemingly unrelated events).'),
#  ('Written Expression',
#   'The ability to communicate information and ideas in writing so others will understand.'),
#  ('Originality',
#   'The ability to come up with unusual or clever ideas about a given topic or situation, or to develop creative ways to solve a problem.'),
#  ('Number Facility',
#   'The ability to add, subtract, multiply, or divide quickly and correctly.')]

# %%
[(competency.other_attributes['competencyText'],competency.name) for competency in computer_scientists.competencies if competency.categories[0] == 'Technology Skills']
# Out:
# [('Configuration management software',
#   'Perforce Software Configuration Management System'),
#  ('Data base management system software',
#   'Relational database management system software'),
#  ('Office suite software', 'Microsoft Office'),
#  ('Computer aided design CAD software', 'PTC Creo Parametric'),
#  ('Clustering software', 'Clustermatic'),
#  ('Development environment software', 'Software libraries'),
#  ('Operating system software', 'VME PowerPC VxWorks'),
#  ('Communications server software', 'IBM Domino'),
#  ('Development environment software', 'Ruby'),
#  ('Analytical or scientific software', 'Augmint'),
#  ('Development environment software',
#   'Formula translation/translator FORTRAN'),
#  ('Analytical or scientific software', 'The MathWorks MATLAB'),
#  ('Development environment software', 'Source code management SCM software'),
#  ('Web platform development software', 'Django'),
#  ('Business intelligence and data analysis software', 'Qlik Tech QlikView'),
#  ('Data base user interface and query software',
#   'Structured query language SQL'),
#  ('Analytical or scientific software', 'Simulation software'),
#  ('Object or component oriented development software',
#   'Microsoft Visual Basic.NET'),
#  ('Analytical or scientific software', 'Algorithmic software'),
#  ('Data base management system software', 'MongoDB'),
#  ('Clustering software', 'Parallel systems software'),
#  ('Data mining software', 'Google Analytics'),
#  ('Object or component oriented development software', 'Oracle Java'),
#  ('File versioning software', 'Git'),
#  ('Enterprise application integration software',
#   'Extensible markup language XML'),
#  ('Presentation software', 'Microsoft PowerPoint'),
#  ('Analytical or scientific software', 'Advanced numerical software'),
#  ('Operating system software', 'Bash'),
#  ('Metadata management software', 'CA Erwin Data Modeler'),
#  ('Data base user interface and query software', 'Amazon Redshift'),
#  ('Analytical or scientific software', 'SAS'),
#  ('Data base management system software', 'Oracle DBMS'),
#  ('Configuration management software', 'IBM Rational Apex'),
#  ('Computer aided design CAD software',
#   'Computer aided design and drafting CADD software'),
#  ('Data base management system software', 'NoSQL'),
#  ('Data base management system software', 'Teradata Database'),
#  ('Development environment software', 'Prolog'),
#  ('Data base management system software', 'Apache Pig'),
#  ('Web platform development software', 'PHP: Hypertext Preprocessor'),
#  ('Data base management system software', 'Apache Solr'),
#  ('Data mining software', 'Data mining software'),
#  ('Development environment software',
#   'Intel Integrated Performance Primitives'),
#  ('Analytical or scientific software', 'IBM SPSS Statistics'),
#  ('Object oriented data base management software', 'PostgreSQL'),
#  ('Object or component oriented development software', 'Jupyter Notebook'),
#  ('Object or component oriented development software', 'Charm++'),
#  ('Business intelligence and data analysis software', 'MicroStrategy'),
#  ('Object or component oriented development software', 'C++'),
#  ('Web platform development software',
#   'Extensible stylesheet language transformations XSLT'),
#  ('Development environment software', 'CMAKE'),
#  ('Development environment software', 'Ada'),
#  ('Object or component oriented development software', 'R'),
#  ('Map creation software', 'ESRI ArcGIS software'),
#  ('Data base management system software', 'Apache Flume'),
#  ('Application server software', 'GitHub'),
#  ('Object or component oriented development software', 'C#'),
#  ('Enterprise application integration software', 'IBM InfoSphere DataStage'),
#  ('Requirements analysis and system architecture software',
#   'Unified modeling language UML'),
#  ('Data base management system software', 'Apache Hadoop'),
#  ('Analytical or scientific software', 'Minitab'),
#  ('Operating system software', 'Linux'),
#  ('Operating system software', 'UNIX'),
#  ('Clustering software', 'Clustering software'),
#  ('Data base management system software', 'MySQL'),
#  ('Development environment software',
#   'Automated document generation software'),
#  ('Operating system software', 'Sun Microsystems Solaris'),
#  ('Compiler and decompiler software',
#   'Low-level virtual machine LLVM compilers'),
#  ('Business intelligence and data analysis software', 'IBM Cognos Impromptu'),
#  ('Development environment software', 'Microsoft Visual Basic'),
#  ('Development environment software', 'C'),
#  ('Development environment software', 'IBM Rational Rose'),
#  ('Project management software', 'Microsoft Project'),
#  ('Web platform development software', 'JavaScript'),
#  ('Graphical user interface development software',
#   'Waikato Environment for Knowledge Analysis Weka'),
#  ('Object or component oriented development software', 'Eiffel'),
#  ('Analytical or scientific software', 'Data visualization software'),
#  ('Enterprise resource planning ERP software', 'SAP Business Objects'),
#  ('Development environment software', 'Embarcadero JBuilder'),
#  ('Analytical or scientific software', 'Polhemus Fasttrack System'),
#  ('Analytical or scientific software',
#   'Multisensory data representation software'),
#  ('Web page creation and editing software', 'Plug-in file software'),
#  ('Development environment software', 'Eclipse IDE'),
#  ('Data base management system software',
#   'Relational database management software'),
#  ('Analytical or scientific software', 'Computational statistics software'),
#  ('Analytical or scientific software', 'Optimization software'),
#  ('Development environment software',
#   'Integrated development environment IDE software'),
#  ('Operating system software', 'Shell script'),
#  ('Operating system software', 'Oracle Solaris'),
#  ('Analytical or scientific software',
#   'Rice Simulator for ILP Multiprocessors RSIM'),
#  ('Development environment software', 'List processing language LISP'),
#  ('Development environment software', 'Apache Kafka'),
#  ('Analytical or scientific software', 'StataCorp Stata'),
#  ('Development environment software', 'National Instruments LabVIEW'),
#  ('Development environment software',
#   'Sun Microsystems Java 2 Platform Enterprise Edition J2EE'),
#  ('Object or component oriented development software', 'Python'),
#  ('Graphics or photo imaging software',
#   'Three-dimensional 3D graphics software'),
#  ('Operating system software', 'Ubuntu'),
#  ('Development environment software', 'Microsoft Visual Studio'),
#  ('Data base user interface and query software', 'Microsoft SQL Server'),
#  ('Object or component oriented development software', 'Microsoft ActiveX'),
#  ('Analytical or scientific software', 'Mathematical software'),
#  ('Portal server software', 'Apache HTTP Server'),
#  ('Data base user interface and query software', 'Apache Hive'),
#  ('Compiler and decompiler software', 'Greenhills Ada compilers'),
#  ('Map creation software', 'Geographic information system GIS software'),
#  ('Data base user interface and query software', 'Data entry software'),
#  ('Object or component oriented development software',
#   'Microsoft Visual C# .NET'),
#  ('Operating system software', 'Microsoft Windows XP'),
#  ('Object or component oriented development software',
#   'Practical extraction and reporting language Perl'),
#  ('Development environment software', 'Microsoft Azure'),
#  ('Development environment software', 'Verilog'),
#  ('Development environment software', 'Microsoft Visual Studio.NET'),
#  ('Compiler and decompiler software', 'Polaris parallelizing compilers'),
#  ('Development environment software', 'Doxygen'),
#  ('Video creation and editing software', 'Video editing software'),
#  ('Business intelligence and data analysis software',
#   'Oracle Business Intelligence Enterprise Edition'),
#  ('Business intelligence and data analysis software', 'Tableau'),
#  ('Analytical or scientific software', 'Intel Math Kernel Library'),
#  ('Development environment software', 'High-performance software libraries'),
#  ('Sales and marketing software', 'Google AdWords'),
#  ('Data base management system software', 'Apache Cassandra'),
#  ('Object or component oriented development software',
#   'Object oriented development environment software'),
#  ('Object or component oriented development software', 'Scala'),
#  ('Graphics or photo imaging software', 'Open Graphics Library OpenGL'),
#  ('Spreadsheet software', 'Microsoft Excel'),
#  ('Enterprise system management software', 'Splunk Enterprise'),
#  ('Data base management system software', 'Elasticsearch'),
#  ('Graphics or photo imaging software', 'Graphics pipelines')]

# %%
[(competency.other_attributes['competencyText'],competency.name) for competency in computer_scientists.competencies if competency.categories[0] == 'Tools Used']
# Out:
# [('High capacity removable media drives',
#   'Universal serial bus USB flash drives'),
#  ('Hard disk drives', 'Hard disk drives'),
#  ('High end computer servers', 'Cluster systems'),
#  ('Hard disk arrays', 'Network storage arrays'),
#  ('Scanners', 'Computer scanners'),
#  ('High end computer servers', 'Massively parallel processors MPP'),
#  ('Loudspeakers', 'Free-field speakers'),
#  ('Laser printers', 'Computer laser printers'),
#  ('Pick or place robots', 'Articulated robots'),
#  ('Multimedia projectors', 'Video projectors'),
#  ('High end computer servers', 'High end computer servers'),
#  ('Scanners', 'Laser scanners'),
#  ('Stage or projection or studio lighting system', 'Lighting grids'),
#  ('Camera based vision systems for automated data collection',
#   'Real time motion capture systems'),
#  ('Digital cameras', 'Digital cameras'),
#  ('Cinematographic cameras', 'Pan-tilt-zoom cameras'),
#  ('Compact disks CDs', 'Magneto optical discs'),
#  ('Personal computers', 'Personal computers'),
#  ('High end computer servers', 'Render farms'),
#  ('Network interface cards', 'Network interface cards NIC'),
#  ('Tape arrays', 'Quarter inch cartridge QIC tapes'),
#  ('Pick or place robots', 'Mobile robots'),
#  ('Camera based vision systems for automated data collection',
#   'Image capture devices'),
#  ('Content delivery networking equipment', 'High-speed networking testbeds'),
#  ('Computer servers', 'Web servers'),
#  ('Microprocessors', 'Microcomputers'),
#  ('High end computer servers', 'High-performance cluster HPC computers'),
#  ('Mainframe computers', 'Mainframe computers'),
#  ('Multimedia projectors', 'Stereographic projectors'),
#  ('Digital camcorders or video cameras', 'Digital video cameras'),
#  ('Graphics tablets', 'Graphics workstations'),
#  ('Computer servers', 'File servers'),
#  ('High end computer servers', 'Distributed heterogeneous computers')]

# %%
[(competency.name,competency.other_attributes['competencyText']) for competency in computer_scientists.competencies if competency.categories[0] == 'Work Activities']
# Out:
# [('Monitor Processes, Materials, or Surroundings',
#   'Monitoring and reviewing information from materials, events, or the environment, to detect or assess problems.'),
#  ('Training and Teaching Others',
#   'Identifying the educational needs of others, developing formal educational or training programs or classes, and teaching or instructing others.'),
#  ('Judging the Qualities of Things, Services, or People',
#   'Assessing the value, importance, or quality of things or people.'),
#  ('Making Decisions and Solving Problems',
#   'Analyzing information and evaluating results to choose the best solution and solve problems.'),
#  ('Updating and Using Relevant Knowledge',
#   'Keeping up-to-date technically and applying new knowledge to your job.'),
#  ('Provide Consultation and Advice to Others',
#   'Providing guidance and expert advice to management or other groups on technical, systems-, or process-related topics.'),
#  ('Establishing and Maintaining Interpersonal Relationships',
#   'Developing constructive and cooperative working relationships with others, and maintaining them over time.'),
#  ('Scheduling Work and Activities',
#   'Scheduling events, programs, and activities, as well as the work of others.'),
#  ('Processing Information',
#   'Compiling, coding, categorizing, calculating, tabulating, auditing, or verifying information or data.'),
#  ('Documenting/Recording Information',
#   'Entering, transcribing, recording, storing, or maintaining information in written or electronic/magnetic form.'),
#  ('Getting Information',
#   'Observing, receiving, and otherwise obtaining information from all relevant sources.'),
#  ('Communicating with Supervisors, Peers, or Subordinates',
#   'Providing information to supervisors, co-workers, and subordinates by telephone, in written form, e-mail, or in person.'),
#  ('Estimating the Quantifiable Characteristics of Products, Events, or Information',
#   'Estimating sizes, distances, and quantities; or determining time, costs, resources, or materials needed to perform a work activity.'),
#  ('Thinking Creatively',
#   'Developing, designing, or creating new applications, ideas, relationships, systems, or products, including artistic contributions.'),
#  ('Communicating with Persons Outside Organization',
#   'Communicating with people outside the organization, representing the organization to customers, the public, government, and other external sources. This information can be exchanged in person, in writing, or by telephone or e-mail.'),
#  ('Interacting With Computers',
#   'Using computers and computer systems (including hardware and software) to program, write software, set up functions, enter data, or process information.'),
#  ('Interpreting the Meaning of Information for Others',
#   'Translating or explaining what information means and how it can be used.'),
#  ('Evaluating Information to Determine Compliance with Standards',
#   'Using relevant information and individual judgment to determine whether events or processes comply with laws, regulations, or standards.'),
#  ('Developing Objectives and Strategies',
#   'Establishing long-range objectives and specifying the strategies and actions to achieve them.'),
#  ('Organizing, Planning, and Prioritizing Work',
#   'Developing specific goals and plans to prioritize, organize, and accomplish your work.'),
#  ('Analyzing Data or Information',
#   'Identifying the underlying principles, reasons, or facts of information by breaking down information or data into separate parts.'),
#  ('Identifying Objects, Actions, and Events',
#   'Identifying information by categorizing, estimating, recognizing differences or similarities, and detecting changes in circumstances or events.')]

# %%
[(competency.name,competency.other_attributes['competencyText']) for competency in computer_scientists.competencies if competency.categories[0] == 'Work Styles']
# Out:
# [('Self Control',
#   'Job requires maintaining composure, keeping emotions in check, controlling anger, and avoiding aggressive behavior, even in very difficult situations.'),
#  ('Adaptability/Flexibility',
#   'Job requires being open to change (positive or negative) and to considerable variety in the workplace.'),
#  ('Independence',
#   "Job requires developing one's own ways of doing things, guiding oneself with little or no supervision, and depending on oneself to get things done."),
#  ('Persistence', 'Job requires persistence in the face of obstacles.'),
#  ('Integrity', 'Job requires being honest and ethical.'),
#  ('Dependability',
#   'Job requires being reliable, responsible, and dependable, and fulfilling obligations.'),
#  ('Achievement/Effort',
#   'Job requires establishing and maintaining personally challenging achievement goals and exerting effort toward mastering tasks.'),
#  ('Analytical Thinking',
#   'Job requires analyzing information and using logic to address work-related issues and problems.'),
#  ('Attention to Detail',
#   'Job requires being careful about detail and thorough in completing work tasks.'),
#  ('Concern for Others',
#   "Job requires being sensitive to others' needs and feelings and being understanding and helpful on the job."),
#  ('Stress Tolerance',
#   'Job requires accepting criticism and dealing calmly and effectively with high stress situations.'),
#  ('Leadership',
#   'Job requires a willingness to lead, take charge, and offer opinions and direction.'),
#  ('Initiative',
#   'Job requires a willingness to take on responsibilities and challenges.'),
#  ('Social Orientation',
#   'Job requires preferring to work with others rather than alone, and being personally connected with others on the job.'),
#  ('Cooperation',
#   'Job requires being pleasant with others on the job and displaying a good-natured, cooperative attitude.'),
#  ('Innovation',
#   'Job requires creativity and alternative thinking to develop new ideas for and answers to work-related problems.')]

# %%
[(competency.name,competency.other_attributes['competencyText']) for competency in computer_scientists.competencies if competency.categories[0] == 'Work Values']
# Out:
# [('Relationships',
#   'Occupations that satisfy this work value allow employees to provide service to others and work with co-workers in a friendly non-competitive environment. Corresponding needs are Co-workers, Moral Values and Social Service.'),
#  ('Independence',
#   'Occupations that satisfy this work value allow employees to work on their own and make decisions. Corresponding needs are Creativity, Responsibility and Autonomy.'),
#  ('Achievement',
#   'Occupations that satisfy this work value are results oriented and allow employees to use their strongest abilities, giving them a feeling of accomplishment. Corresponding needs are Ability Utilization and Achievement.'),
#  ('Support',
#   'Occupations that satisfy this work value offer supportive management that stands behind employees. Corresponding needs are Company Policies, Supervision: Human Relations and Supervision: Technical.'),
#  ('Working Conditions',
#   'Occupations that satisfy this work value offer job security and good working conditions. Corresponding needs are Activity, Compensation, Independence, Security, Variety and Working Conditions.'),
#  ('Recognition',
#   'Occupations that satisfy this work value offer advancement, potential for leadership, and are often considered prestigious. Corresponding needs are Advancement, Authority, Recognition and Social Status.')]

# %%
[(competency.name,competency.other_attributes['competencyType']) for competency in computer_scientists.competencies if competency.categories[0] == 'Task Statements']
# Out:
# [('Evaluate project plans and proposals to assess feasibility issues.',
#   'Core'),
#  ('Participate in staffing decisions and direct training of subordinates.',
#   'Supplemental'),
#  ('Consult with users, management, vendors, and technicians to determine computing needs and system requirements.',
#   'Core'),
#  ('Conduct logical analyses of business, scientific, engineering, and other technical problems, formulating mathematical models of problems for solution by computers.',
#   'Core'),
#  ('Direct daily operations of departments, coordinating project activities with other departments.',
#   'Supplemental'),
#  ('Develop and interpret organizational goals, policies, and procedures.',
#   'Core'),
#  ('Approve, prepare, monitor, and adjust operational budgets.',
#   'Supplemental'),
#  ('Develop performance standards, and evaluate work in light of established standards.',
#   'Core'),
#  ('Analyze problems to develop solutions involving computer hardware and software.',
#   'Core'),
#  ('Design computers and the software that runs them.', 'Core'),
#  ('Apply theoretical expertise and innovation to create or apply new technology, such as adapting principles for applying computers to new uses.',
#   'Core'),
#  ('Participate in multidisciplinary projects in areas such as virtual reality, human-computer interaction, or robotics.',
#   'Core'),
#  ('Assign or schedule tasks to meet work priorities and goals.', 'Core'),
#  ('Meet with managers, vendors, and others to solicit cooperation and resolve problems.',
#   'Core'),
#  ('Maintain network hardware and software, direct network security measures, and monitor networks to ensure availability to system users.',
#   'Supplemental')]

# %%
computer_scientists.occupations
# Out:
# {Occupation(identifier=15-1111.00, name=Computer and Information Research Scientists, {'description': 'Conduct research into fundamental computer and information science as theorists, designers, or inventors. Develop solutions to problems in the field of computer hardware and software.', 'categories': ['O*NET-SOC Occupation']})}

# %%
import pandas as pd

# %%
columns = ['occupation', 'competency', 'category', 'description']
data = []
occupations = ['Computer and Information Research Scientists', 
               'Social Science Research Assistants', 
               'Remote Sensing Scientists and Technologists',
               'Bioinformatics Scientists',
               'Geospatial Information Scientists and Technologists',
               'Survey Researchers',
               'Statisticians',
               'Computer Systems Analysts',
               'Mathematicians',
               'Software Developers, Systems Software',
               'Database Administrators',
               'Database Architects',
               'Database Administrators',
               'Data Warehousing Specialists',
               'Computer Systems Engineers/Architects',
               'Business Intelligence Analysts',
               'Financial Quantitative Analysts',
               'Clinical Data Managers',
               'Information Security Analysts',
               'Clinical Data Managers'
              ]
for occupation in occupations:
    oc = myonet.filter_by(lambda edge: occupation in edge.occupation.name)
    for competency in oc.competencies:
        row = [occupation, competency.name, competency.categories[0], competency.other_attributes['competencyText']]
        data.append(row)
df = pd.DataFrame(data, columns=columns)

# %%
df.head(10)
# Out:
#                                      occupation  \
# 0  Computer and Information Research Scientists
# 1  Computer and Information Research Scientists
# 2  Computer and Information Research Scientists
# 3  Computer and Information Research Scientists
# 4  Computer and Information Research Scientists
# 5  Computer and Information Research Scientists
# 6  Computer and Information Research Scientists
# 7  Computer and Information Research Scientists
# 8  Computer and Information Research Scientists
# 9  Computer and Information Research Scientists
#
#                                           competency           category  \
# 0                Source code management SCM software  Technology Skills
# 1                                    Microsoft Azure  Technology Skills
# 2                                      Visualization          Abilities
# 3                                Free-field speakers         Tools Used
# 4                        Data visualization software  Technology Skills
# 5                       Judgment and Decision Making             Skills
# 6                                              Linux  Technology Skills
# 7                                  IBM Rational Apex  Technology Skills
# 8                                            Minitab  Technology Skills
# 9  Evaluate project plans and proposals to assess...    Task Statements
#
#                                          description
# 0                   Development environment software
# 1                   Development environment software
# 2  The ability to imagine how something will look...
# 3                                       Loudspeakers
# 4                  Analytical or scientific software
# 5  Considering the relative costs and benefits of...
# 6                          Operating system software
# 7                  Configuration management software
# 8                  Analytical or scientific software
# 9                                               Core

# %%
output_file = '../../datasets/competencies.csv'
df.to_csv(output_file)

# %%
oc_columns = ['identifier', 'name', 'description', 'titles']
oc_data = []
for occupation_title in occupations:
    oc = myonet.filter_by(lambda edge: occupation_title in edge.occupation.name)
    for occupation in oc.occupations:
        row = [occupation.identifier, occupation.name, occupation.other_attributes['description'], ','.join(occupation.other_attributes['alternate_titles'])]
        oc_data.append(row)
oc_df = pd.DataFrame(oc_data, columns=oc_columns)

# %%
oc_df.head(10)
# Out:
#    identifier                                               name  \
# 0  15-1111.00       Computer and Information Research Scientists
# 1  19-4061.00                 Social Science Research Assistants
# 2  19-2099.01        Remote Sensing Scientists and Technologists
# 3  19-1029.01                          Bioinformatics Scientists
# 4  15-1199.04  Geospatial Information Scientists and Technolo...
# 5  19-3022.00                                 Survey Researchers
# 6  15-2041.00                                      Statisticians
# 7  15-1121.00                          Computer Systems Analysts
# 8  15-2021.00                                     Mathematicians
# 9  15-1133.00              Software Developers, Systems Software
#
#                                          description  \
# 0  Conduct research into fundamental computer and...
# 1  Assist social scientists in laboratory, survey...
# 2  Apply remote sensing principles and methods to...
# 3  Conduct research using bioinformatics theory a...
# 4  Research or develop geospatial technologies. M...
# 5  Plan, develop, or conduct surveys. May analyze...
# 6  Develop or apply mathematical or statistical t...
# 7  Analyze science, engineering, business, and ot...
# 8  Conduct research in fundamental mathematics or...
# 9  Research, design, develop, and test operating ...
#
#                                               titles
# 0  Artificial Intelligence Specialist (AI Special...
# 1  Bilingual Research Interviewer,Clinical Resear...
# 2  All Source Intelligence Analyst,Data Analytics...
# 3  Assistant Scientist,Bioinformatician,Bioinform...
# 4  Geographic Information Scientist,Geographic In...
# 5  Data Analyst,Data Collection Specialist,Field ...
# 6  Analytical Statistician,Applied Scientist,Appl...
# 7  Applications Analyst,Applications Systems Anal...
# 8  Agent-Based Modeler,Algebraist,Applied Mathema...
# 9  Applications Analyst,Automation Engineer,Beta ...

# %%
output_file = '../../datasets/occupations.csv'
oc_df.to_csv(output_file)
