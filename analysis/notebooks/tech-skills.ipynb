# %%
import numpy as np
import pandas as pd
import sqlite3
import spacy

# %%
# Download pretrained enlgish model
try:
    import en_core_web_sm
except:
    # !python -m spacy download en_core_web_sm
    import en_core_web_sm

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("../../collectors/data.sqlite3")
job_df = pd.read_sql_query("SELECT * from job_post", con)
con.close()

# %%
# Verify that result of SQL query is stored in the dataframe
job_df.head()
# Out:
#    id                                 title                   company  \
# 0   1                        Data Scientist       Aquatic Informatics
# 1   2         Business Intelligence Analyst                   GLENTEL
# 2   3        Human Resources Data Scientist                 Rio Tinto
# 3   4  Lead - Human Resource Data Scientist                 Rio Tinto
# 4   5             Machine Learning Engineer  Skycope Technologies Inc
#
#         location                                        description  \
# 0  Vancouver, BC  Do you want a meaningful role in a company tha...
# 1    Burnaby, BC  Brand: Glentel Corporate\nLocation: Burnaby Of...
# 2         Canada  2 x newly created Data Scientist opportunities...
# 3         Canada  Newly created data science lead embedded withi...
# 4  Vancouver, BC  Who We are\nFounded in 2016, Skycope Technolog...
#
#        source       search_kw
# 0  indeed.com  data scientist
# 1  indeed.com  data scientist
# 2  indeed.com  data scientist
# 3  indeed.com  data scientist
# 4  indeed.com  data scientist

# %%
onet_competencies = '../../datasets/competencies.csv'
onet_df = pd.read_csv(onet_competencies,index_col=0)
onet_df[onet_df['occupation'] == 'Computer and Information Research Scientists'].head(5)
# Out:
#                                      occupation  \
# 0  Computer and Information Research Scientists
# 1  Computer and Information Research Scientists
# 2  Computer and Information Research Scientists
# 3  Computer and Information Research Scientists
# 4  Computer and Information Research Scientists
#
#                             competency           category  \
# 0  Source code management SCM software  Technology Skills
# 1                      Microsoft Azure  Technology Skills
# 2                        Visualization          Abilities
# 3                  Free-field speakers         Tools Used
# 4          Data visualization software  Technology Skills
#
#                                          description
# 0                   Development environment software
# 1                   Development environment software
# 2  The ability to imagine how something will look...
# 3                                       Loudspeakers
# 4                  Analytical or scientific software

# %%
def process_text(text):
    doc = nlp(text)
    result = []
    for token in doc:
        if token.text in nlp.Defaults.stop_words:
            continue
        if token.is_punct:
            continue
        if token.lemma_ == '-PRON-':
            continue
        # result.append(token.lemma_)
        result.append(token.text)
    return " ".join(result)

# %%
nlp = en_core_web_sm.load()
nlp.Defaults.stop_words.add("\n")

# %%
onet_comp = np.array(onet_df['competency'])
onet_desc = np.array(onet_df['description'])

# %%
onet_comp = np.array([process_text(comp.lower()) for comp in onet_comp])
onet_desc = np.array([process_text(desc.lower()) for desc in onet_desc])

# %%
# Filter ONet DF to keep only required category of competencies

category_list = ['Abilities', 'Technology Skills', 'Tools Used', 'Knowledge', 'Skills']

print("ONET length before filter: ", len(onet_df))
filtered_onet_df = onet_df.loc[onet_df['category'].isin(category_list)]
print("ONET length after filter:  ", len(filtered_onet_df))
filtered_onet_df.head(5)
# Out:
# ONET length before filter:  4938
# ONET length after filter:   3702
#                                      occupation  \
# 0  Computer and Information Research Scientists
# 1  Computer and Information Research Scientists
# 2  Computer and Information Research Scientists
# 3  Computer and Information Research Scientists
# 4  Computer and Information Research Scientists
#
#                             competency           category  \
# 0  Source code management SCM software  Technology Skills
# 1                      Microsoft Azure  Technology Skills
# 2                        Visualization          Abilities
# 3                  Free-field speakers         Tools Used
# 4          Data visualization software  Technology Skills
#
#                                          description
# 0                   Development environment software
# 1                   Development environment software
# 2  The ability to imagine how something will look...
# 3                                       Loudspeakers
# 4                  Analytical or scientific software

# %%
occupations = 'results/title_occupation.csv'
occupations = pd.read_csv(occupations)
occupations['description'] = job_df['description']
occupations.head(5)
# Out:
#    id                                 title  identifier  score_all  \
# 0   1                        Data Scientist  15-1111.00   0.883895
# 1   2         Business Intelligence Analyst  15-1199.08   0.866399
# 2   3        Human Resources Data Scientist  15-1111.00   0.737225
# 3   4  Lead - Human Resource Data Scientist  15-1111.00   0.738833
# 4   5             Machine Learning Engineer  15-1111.00   0.847708
#
#                                            name  \
# 0  Computer and Information Research Scientists
# 1                Business Intelligence Analysts
# 2  Computer and Information Research Scientists
# 3  Computer and Information Research Scientists
# 4  Computer and Information Research Scientists
#
#                                          description
# 0  Do you want a meaningful role in a company tha...
# 1  Brand: Glentel Corporate\nLocation: Burnaby Of...
# 2  2 x newly created Data Scientist opportunities...
# 3  Newly created data science lead embedded withi...
# 4  Who We are\nFounded in 2016, Skycope Technolog...

# %%
job_desc = occupations['description'].values

# %%
job_desc = np.array([desc.lower() for desc in job_desc])

# %%
job_lengths = np.array([len(list(nlp(str(desc)).sents)) for desc in job_desc])

# %%
job_lengths[:15]
# Out:
# array([ 28,  32, 228, 236,  30,  20,  22,  21,  25,  46,  32,  48,  35,
#         38,  23])

# %%
# Choose to keep jobs which have sentences less than a threshold
MAX_SENTENCE_LENGTH = 40
job_ids = np.where(job_lengths < MAX_SENTENCE_LENGTH)[0]

# %%
job_ids[:10]
# Out:
# array([ 0,  1,  4,  5,  6,  7,  8, 10, 12, 13])

# %%
FIRST_N = 50

small_job_desc = job_desc[job_ids][:FIRST_N]

small_job_desc = np.array([np.array([process_text(line.text).replace("\n", '') \
                                for line in nlp(str(desc)).sents]) \
                                for desc in small_job_desc])

# %%
small_job_desc[0][:5]
# Out:
# array(['want meaningful role company making difference world',
#        'want involved important environmental resource areas today',
#        'want learn involved developing deploying machine learning predictive analytics solutions colleagues years research development experience',
#        'join energetic growing team help revolutionize industry',
#        'company founded 2003 aquatic informatics provides software solutions address critical water data management analytics compliance challenges rapidly growing water industry'],
#       dtype='<U368')

# %%
# ***************************************************************
# BEWARE: EXTREMELY TIME CONSUMING
# TRY FOR SMALL NUMBER OF JOBS
# IMPRACTICAL FOR A LARGE SET OF JOBS SIMULTANEOUSLY
# PRACTICAL IMPLICATION: PERFORM THIS WHENEVER A NEW JOB IS ADDED
# ***************************************************************

scores = []
comp_ids = []

for i, desc in enumerate(small_job_desc):
    title = occupations['name'].iloc[i]
    idss = filtered_onet_df.index[filtered_onet_df['occupation'] == title].tolist()
    sent_score = []
    sent_comp_id = []
    print("COMPETENCIES {}, SENTENCES {}".format(len(idss), len(desc)))
    print("------------------------------")
    for j, sentence in enumerate(desc):
        sentence = nlp(str(sentence))
        temp_score = []
        # temp_comp_id = np.empty()
        for ids in idss:
            sim1 = sentence.similarity(nlp(str(onet_comp[ids])))
            sim2 = sentence.similarity(nlp(str(onet_desc[ids])))
            temp_score.append(max(sim1, sim2))
    
        max_score = np.max(temp_score)
        max_comp_id = idss[np.argmax(temp_score)]
        sent_score.append(max_score)
        sent_comp_id.append(max_comp_id)
        print("JOB {}, SENTENCE {} DONE".format(i, j))

    scores.append(sent_score)
    comp_ids.append(sent_comp_id)
# Out:
# -----------------------------
# JOB 21, SENTENCE 0 DONE
# JOB 21, SENTENCE 1 DONE
# JOB 21, SENTENCE 2 DONE
# JOB 21, SENTENCE 3 DONE
# JOB 21, SENTENCE 4 DONE
# JOB 21, SENTENCE 5 DONE
# JOB 21, SENTENCE 6 DONE
# JOB 21, SENTENCE 7 DONE
# JOB 21, SENTENCE 8 DONE
# JOB 21, SENTENCE 9 DONE
# JOB 21, SENTENCE 10 DONE
# JOB 21, SENTENCE 11 DONE
# JOB 21, SENTENCE 12 DONE
# JOB 21, SENTENCE 13 DONE
# JOB 21, SENTENCE 14 DONE
# JOB 21, SENTENCE 15 DONE
# JOB 21, SENTENCE 16 DONE
# JOB 21, SENTENCE 17 DONE
# JOB 21, SENTENCE 18 DONE
# JOB 21, SENTENCE 19 DONE
# JOB 21, SENTENCE 20 DONE
# JOB 21, SENTENCE 21 DONE
# JOB 21, SENTENCE 22 DONE
# JOB 21, SENTENCE 23 DONE
# JOB 21, SENTENCE 24 DONE
# COMPETENCIES 208, SENTENCES 12
# ------------------------------
# JOB 22, SENTENCE 0 DONE
# JOB 22, SENTENCE 1 DONE
# JOB 22, SENTENCE 2 DONE
# JOB 22, SENTENCE 3 DONE
# JOB 22, SENTENCE 4 DONE
# JOB 22, SENTENCE 5 DONE
# JOB 22, SENTENCE 6 DONE
# JOB 22, SENTENCE 7 DONE
# JOB 22, SENTENCE 8 DONE
# JOB 22, SENTENCE 9 DONE
# JOB 22, SENTENCE 10 DONE
# JOB 22, SENTENCE 11 DONE
# COMPETENCIES 208, SENTENCES 35
# ------------------------------
# JOB 23, SENTENCE 0 DONE
# JOB 23, SENTENCE 1 DONE
# JOB 23, SENTENCE 2 DONE
# JOB 23, SENTENCE 3 DONE
# JOB 23, SENTENCE 4 DONE
# JOB 23, SENTENCE 5 DONE
# JOB 23, SENTENCE 6 DONE
# JOB 23, SENTENCE 7 DONE
# JOB 23, SENTENCE 8 DONE
# JOB 23, SENTENCE 9 DONE
# JOB 23, SENTENCE 10 DONE
# JOB 23, SENTENCE 11 DONE
# JOB 23, SENTENCE 12 DONE
# JOB 23, SENTENCE 13 DONE
# JOB 23, SENTENCE 14 DONE
# JOB 23, SENTENCE 15 DONE
# JOB 23, SENTENCE 16 DONE
# JOB 23, SENTENCE 17 DONE
# JOB 23, SENTENCE 18 DONE
# JOB 23, SENTENCE 19 DONE
# JOB 23, SENTENCE 20 DONE
# JOB 23, SENTENCE 21 DONE
# JOB 23, SENTENCE 22 DONE
# JOB 23, SENTENCE 23 DONE
# JOB 23, SENTENCE 24 DONE
# JOB 23, SENTENCE 25 DONE
# JOB 23, SENTENCE 26 DONE
# JOB 23, SENTENCE 27 DONE
# JOB 23, SENTENCE 28 DONE
# JOB 23, SENTENCE 29 DONE
# JOB 23, SENTENCE 30 DONE
# JOB 23, SENTENCE 31 DONE
# JOB 23, SENTENCE 32 DONE
# JOB 23, SENTENCE 33 DONE
# JOB 23, SENTENCE 34 DONE
# COMPETENCIES 208, SENTENCES 14
# ------------------------------
# JOB 24, SENTENCE 0 DONE
# JOB 24, SENTENCE 1 DONE
# JOB 24, SENTENCE 2 DONE
# JOB 24, SENTENCE 3 DONE
# JOB 24, SENTENCE 4 DONE
# JOB 24, SENTENCE 5 DONE
# JOB 24, SENTENCE 6 DONE
# JOB 24, SENTENCE 7 DONE
# JOB 24, SENTENCE 8 DONE
# JOB 24, SENTENCE 9 DONE
# JOB 24, SENTENCE 10 DONE
# JOB 24, SENTENCE 11 DONE
# JOB 24, SENTENCE 12 DONE
# JOB 24, SENTENCE 13 DONE
# COMPETENCIES 292, SENTENCES 15
# ------------------------------
# JOB 25, SENTENCE 0 DONE
# JOB 25, SENTENCE 1 DONE
# JOB 25, SENTENCE 2 DONE
# JOB 25, SENTENCE 3 DONE
# JOB 25, SENTENCE 4 DONE
# JOB 25, SENTENCE 5 DONE
# JOB 25, SENTENCE 6 DONE
# JOB 25, SENTENCE 7 DONE
# JOB 25, SENTENCE 8 DONE
# JOB 25, SENTENCE 9 DONE
# JOB 25, SENTENCE 10 DONE
# JOB 25, SENTENCE 11 DONE
# JOB 25, SENTENCE 12 DONE
# JOB 25, SENTENCE 13 DONE
# JOB 25, SENTENCE 14 DONE
# COMPETENCIES 618, SENTENCES 32
# ------------------------------
# JOB 26, SENTENCE 0 DONE
# JOB 26, SENTENCE 1 DONE
# JOB 26, SENTENCE 2 DONE
# JOB 26, SENTENCE 3 DONE
# JOB 26, SENTENCE 4 DONE
# JOB 26, SENTENCE 5 DONE
# JOB 26, SENTENCE 6 DONE
# JOB 26, SENTENCE 7 DONE
# JOB 26, SENTENCE 8 DONE
# JOB 26, SENTENCE 9 DONE
# JOB 26, SENTENCE 10 DONE
# JOB 26, SENTENCE 11 DONE
# JOB 26, SENTENCE 12 DONE
# JOB 26, SENTENCE 13 DONE
# JOB 26, SENTENCE 14 DONE
# JOB 26, SENTENCE 15 DONE
# JOB 26, SENTENCE 16 DONE
# JOB 26, SENTENCE 17 DONE
# JOB 26, SENTENCE 18 DONE
# JOB 26, SENTENCE 19 DONE
# JOB 26, SENTENCE 20 DONE
# JOB 26, SENTENCE 21 DONE
# JOB 26, SENTENCE 22 DONE
# JOB 26, SENTENCE 23 DONE
# JOB 26, SENTENCE 24 DONE
# JOB 26, SENTENCE 25 DONE
# JOB 26, SENTENCE 26 DONE
# JOB 26, SENTENCE 27 DONE
# JOB 26, SENTENCE 28 DONE
# JOB 26, SENTENCE 29 DONE
# JOB 26, SENTENCE 30 DONE
# JOB 26, SENTENCE 31 DONE
# COMPETENCIES 62, SENTENCES 20
# ------------------------------
# JOB 27, SENTENCE 0 DONE
# JOB 27, SENTENCE 1 DONE
# JOB 27, SENTENCE 2 DONE
# JOB 27, SENTENCE 3 DONE
# JOB 27, SENTENCE 4 DONE
# JOB 27, SENTENCE 5 DONE
# JOB 27, SENTENCE 6 DONE
# JOB 27, SENTENCE 7 DONE
# JOB 27, SENTENCE 8 DONE
# JOB 27, SENTENCE 9 DONE
# JOB 27, SENTENCE 10 DONE
# JOB 27, SENTENCE 11 DONE
# JOB 27, SENTENCE 12 DONE
# JOB 27, SENTENCE 13 DONE
# JOB 27, SENTENCE 14 DONE
# JOB 27, SENTENCE 15 DONE
# JOB 27, SENTENCE 16 DONE
# JOB 27, SENTENCE 17 DONE
# JOB 27, SENTENCE 18 DONE
# JOB 27, SENTENCE 19 DONE
# COMPETENCIES 333, SENTENCES 22
# ------------------------------
# JOB 28, SENTENCE 0 DONE
# JOB 28, SENTENCE 1 DONE
# JOB 28, SENTENCE 2 DONE
# JOB 28, SENTENCE 3 DONE
# JOB 28, SENTENCE 4 DONE
# JOB 28, SENTENCE 5 DONE
# JOB 28, SENTENCE 6 DONE
# JOB 28, SENTENCE 7 DONE
# JOB 28, SENTENCE 8 DONE
# JOB 28, SENTENCE 9 DONE
# JOB 28, SENTENCE 10 DONE
# JOB 28, SENTENCE 11 DONE
# JOB 28, SENTENCE 12 DONE
# JOB 28, SENTENCE 13 DONE
# JOB 28, SENTENCE 14 DONE
# JOB 28, SENTENCE 15 DONE
# JOB 28, SENTENCE 16 DONE
# JOB 28, SENTENCE 17 DONE
# JOB 28, SENTENCE 18 DONE
# JOB 28, SENTENCE 19 DONE
# JOB 28, SENTENCE 20 DONE
# JOB 28, SENTENCE 21 DONE
# COMPETENCIES 308, SENTENCES 21
# ------------------------------
# JOB 29, SENTENCE 0 DONE
# JOB 29, SENTENCE 1 DONE
# JOB 29, SENTENCE 2 DONE
# JOB 29, SENTENCE 3 DONE
# JOB 29, SENTENCE 4 DONE
# JOB 29, SENTENCE 5 DONE
# JOB 29, SENTENCE 6 DONE
# JOB 29, SENTENCE 7 DONE
# JOB 29, SENTENCE 8 DONE
# JOB 29, SENTENCE 9 DONE
# JOB 29, SENTENCE 10 DONE
# JOB 29, SENTENCE 11 DONE
# JOB 29, SENTENCE 12 DONE
# JOB 29, SENTENCE 13 DONE
# JOB 29, SENTENCE 14 DONE
# JOB 29, SENTENCE 15 DONE
# JOB 29, SENTENCE 16 DONE
# JOB 29, SENTENCE 17 DONE
# JOB 29, SENTENCE 18 DONE
# JOB 29, SENTENCE 19 DONE
# JOB 29, SENTENCE 20 DONE
# COMPETENCIES 208, SENTENCES 25
# ------------------------------
# JOB 30, SENTENCE 0 DONE
# JOB 30, SENTENCE 1 DONE
# JOB 30, SENTENCE 2 DONE
# JOB 30, SENTENCE 3 DONE
# JOB 30, SENTENCE 4 DONE
# JOB 30, SENTENCE 5 DONE
# JOB 30, SENTENCE 6 DONE
# JOB 30, SENTENCE 7 DONE
# JOB 30, SENTENCE 8 DONE
# JOB 30, SENTENCE 9 DONE
# JOB 30, SENTENCE 10 DONE
# JOB 30, SENTENCE 11 DONE
# JOB 30, SENTENCE 12 DONE
# JOB 30, SENTENCE 13 DONE
# JOB 30, SENTENCE 14 DONE
# JOB 30, SENTENCE 15 DONE
# JOB 30, SENTENCE 16 DONE
# JOB 30, SENTENCE 17 DONE
# JOB 30, SENTENCE 18 DONE
# JOB 30, SENTENCE 19 DONE
# JOB 30, SENTENCE 20 DONE
# JOB 30, SENTENCE 21 DONE
# JOB 30, SENTENCE 22 DONE
# JOB 30, SENTENCE 23 DONE
# JOB 30, SENTENCE 24 DONE
# COMPETENCIES 208, SENTENCES 32
# ------------------------------
# JOB 31, SENTENCE 0 DONE
# JOB 31, SENTENCE 1 DONE
# JOB 31, SENTENCE 2 DONE
# JOB 31, SENTENCE 3 DONE
# JOB 31, SENTENCE 4 DONE
# JOB 31, SENTENCE 5 DONE
# JOB 31, SENTENCE 6 DONE
# JOB 31, SENTENCE 7 DONE
# JOB 31, SENTENCE 8 DONE
# JOB 31, SENTENCE 9 DONE
# JOB 31, SENTENCE 10 DONE
# JOB 31, SENTENCE 11 DONE
# JOB 31, SENTENCE 12 DONE
# JOB 31, SENTENCE 13 DONE
# JOB 31, SENTENCE 14 DONE
# JOB 31, SENTENCE 15 DONE
# JOB 31, SENTENCE 16 DONE
# JOB 31, SENTENCE 17 DONE
# JOB 31, SENTENCE 18 DONE
# JOB 31, SENTENCE 19 DONE
# JOB 31, SENTENCE 20 DONE
# JOB 31, SENTENCE 21 DONE
# JOB 31, SENTENCE 22 DONE
# JOB 31, SENTENCE 23 DONE
# JOB 31, SENTENCE 24 DONE
# JOB 31, SENTENCE 25 DONE
# JOB 31, SENTENCE 26 DONE
# JOB 31, SENTENCE 27 DONE
# JOB 31, SENTENCE 28 DONE
# JOB 31, SENTENCE 29 DONE
# JOB 31, SENTENCE 30 DONE
# JOB 31, SENTENCE 31 DONE
# COMPETENCIES 333, SENTENCES 35
# ------------------------------
# JOB 32, SENTENCE 0 DONE
# JOB 32, SENTENCE 1 DONE
# JOB 32, SENTENCE 2 DONE
# JOB 32, SENTENCE 3 DONE
# JOB 32, SENTENCE 4 DONE
# JOB 32, SENTENCE 5 DONE
# JOB 32, SENTENCE 6 DONE
# JOB 32, SENTENCE 7 DONE
# JOB 32, SENTENCE 8 DONE
# JOB 32, SENTENCE 9 DONE
# JOB 32, SENTENCE 10 DONE
# JOB 32, SENTENCE 11 DONE
# JOB 32, SENTENCE 12 DONE
# JOB 32, SENTENCE 13 DONE
# JOB 32, SENTENCE 14 DONE
# JOB 32, SENTENCE 15 DONE
# JOB 32, SENTENCE 16 DONE
# JOB 32, SENTENCE 17 DONE
# JOB 32, SENTENCE 18 DONE
# JOB 32, SENTENCE 19 DONE
# JOB 32, SENTENCE 20 DONE
# JOB 32, SENTENCE 21 DONE
# JOB 32, SENTENCE 22 DONE
# JOB 32, SENTENCE 23 DONE
# JOB 32, SENTENCE 24 DONE
# JOB 32, SENTENCE 25 DONE
# JOB 32, SENTENCE 26 DONE
# JOB 32, SENTENCE 27 DONE
# JOB 32, SENTENCE 28 DONE
# JOB 32, SENTENCE 29 DONE
# JOB 32, SENTENCE 30 DONE
# JOB 32, SENTENCE 31 DONE
# JOB 32, SENTENCE 32 DONE
# JOB 32, SENTENCE 33 DONE
# JOB 32, SENTENCE 34 DONE
# COMPETENCIES 208, SENTENCES 37
# ------------------------------
# JOB 33, SENTENCE 0 DONE
# JOB 33, SENTENCE 1 DONE
# JOB 33, SENTENCE 2 DONE
# JOB 33, SENTENCE 3 DONE
# JOB 33, SENTENCE 4 DONE
# JOB 33, SENTENCE 5 DONE
# JOB 33, SENTENCE 6 DONE
# JOB 33, SENTENCE 7 DONE
# JOB 33, SENTENCE 8 DONE
# JOB 33, SENTENCE 9 DONE
# JOB 33, SENTENCE 10 DONE
# JOB 33, SENTENCE 11 DONE
# JOB 33, SENTENCE 12 DONE
# JOB 33, SENTENCE 13 DONE
# JOB 33, SENTENCE 14 DONE
# JOB 33, SENTENCE 15 DONE
# JOB 33, SENTENCE 16 DONE
# JOB 33, SENTENCE 17 DONE
# JOB 33, SENTENCE 18 DONE
# JOB 33, SENTENCE 19 DONE
# JOB 33, SENTENCE 20 DONE
# JOB 33, SENTENCE 21 DONE
# JOB 33, SENTENCE 22 DONE
# JOB 33, SENTENCE 23 DONE
# JOB 33, SENTENCE 24 DONE
# JOB 33, SENTENCE 25 DONE
# JOB 33, SENTENCE 26 DONE
# JOB 33, SENTENCE 27 DONE
# JOB 33, SENTENCE 28 DONE
# JOB 33, SENTENCE 29 DONE
# JOB 33, SENTENCE 30 DONE
# JOB 33, SENTENCE 31 DONE
# JOB 33, SENTENCE 32 DONE
# JOB 33, SENTENCE 33 DONE
# JOB 33, SENTENCE 34 DONE
# JOB 33, SENTENCE 35 DONE
# JOB 33, SENTENCE 36 DONE
# COMPETENCIES 208, SENTENCES 38
# ------------------------------
# JOB 34, SENTENCE 0 DONE
# JOB 34, SENTENCE 1 DONE
# JOB 34, SENTENCE 2 DONE
# JOB 34, SENTENCE 3 DONE
# JOB 34, SENTENCE 4 DONE
# JOB 34, SENTENCE 5 DONE
# JOB 34, SENTENCE 6 DONE
# JOB 34, SENTENCE 7 DONE
# JOB 34, SENTENCE 8 DONE
# JOB 34, SENTENCE 9 DONE
# JOB 34, SENTENCE 10 DONE
# JOB 34, SENTENCE 11 DONE
# JOB 34, SENTENCE 12 DONE
# JOB 34, SENTENCE 13 DONE
# JOB 34, SENTENCE 14 DONE
# JOB 34, SENTENCE 15 DONE
# JOB 34, SENTENCE 16 DONE
# JOB 34, SENTENCE 17 DONE
# JOB 34, SENTENCE 18 DONE
# JOB 34, SENTENCE 19 DONE
# JOB 34, SENTENCE 20 DONE
# JOB 34, SENTENCE 21 DONE
# JOB 34, SENTENCE 22 DONE
# JOB 34, SENTENCE 23 DONE
# JOB 34, SENTENCE 24 DONE
# JOB 34, SENTENCE 25 DONE
# JOB 34, SENTENCE 26 DONE
# JOB 34, SENTENCE 27 DONE
# JOB 34, SENTENCE 28 DONE
# JOB 34, SENTENCE 29 DONE
# JOB 34, SENTENCE 30 DONE
# JOB 34, SENTENCE 31 DONE
# JOB 34, SENTENCE 32 DONE
# JOB 34, SENTENCE 33 DONE
# JOB 34, SENTENCE 34 DONE
# JOB 34, SENTENCE 35 DONE
# JOB 34, SENTENCE 36 DONE
# JOB 34, SENTENCE 37 DONE
# COMPETENCIES 208, SENTENCES 28
# ------------------------------
# JOB 35, SENTENCE 0 DONE
# JOB 35, SENTENCE 1 DONE
# JOB 35, SENTENCE 2 DONE
# JOB 35, SENTENCE 3 DONE
# JOB 35, SENTENCE 4 DONE
# JOB 35, SENTENCE 5 DONE
# JOB 35, SENTENCE 6 DONE
# JOB 35, SENTENCE 7 DONE
# JOB 35, SENTENCE 8 DONE
# JOB 35, SENTENCE 9 DONE
# JOB 35, SENTENCE 10 DONE
# JOB 35, SENTENCE 11 DONE
# JOB 35, SENTENCE 12 DONE
# JOB 35, SENTENCE 13 DONE
# JOB 35, SENTENCE 14 DONE
# JOB 35, SENTENCE 15 DONE
# JOB 35, SENTENCE 16 DONE
# JOB 35, SENTENCE 17 DONE
# JOB 35, SENTENCE 18 DONE
# JOB 35, SENTENCE 19 DONE
# JOB 35, SENTENCE 20 DONE
# JOB 35, SENTENCE 21 DONE
# JOB 35, SENTENCE 22 DONE
# JOB 35, SENTENCE 23 DONE
# JOB 35, SENTENCE 24 DONE
# JOB 35, SENTENCE 25 DONE
# JOB 35, SENTENCE 26 DONE
# JOB 35, SENTENCE 27 DONE
# COMPETENCIES 224, SENTENCES 28
# ------------------------------
# JOB 36, SENTENCE 0 DONE
# JOB 36, SENTENCE 1 DONE
# JOB 36, SENTENCE 2 DONE
# JOB 36, SENTENCE 3 DONE
# JOB 36, SENTENCE 4 DONE
# JOB 36, SENTENCE 5 DONE
# JOB 36, SENTENCE 6 DONE
# JOB 36, SENTENCE 7 DONE
# JOB 36, SENTENCE 8 DONE
# JOB 36, SENTENCE 9 DONE
# JOB 36, SENTENCE 10 DONE
# JOB 36, SENTENCE 11 DONE
# JOB 36, SENTENCE 12 DONE
# JOB 36, SENTENCE 13 DONE
# JOB 36, SENTENCE 14 DONE
# JOB 36, SENTENCE 15 DONE
# JOB 36, SENTENCE 16 DONE
# JOB 36, SENTENCE 17 DONE
# JOB 36, SENTENCE 18 DONE
# JOB 36, SENTENCE 19 DONE
# JOB 36, SENTENCE 20 DONE
# JOB 36, SENTENCE 21 DONE
# JOB 36, SENTENCE 22 DONE
# JOB 36, SENTENCE 23 DONE
# JOB 36, SENTENCE 24 DONE
# JOB 36, SENTENCE 25 DONE
# JOB 36, SENTENCE 26 DONE
# JOB 36, SENTENCE 27 DONE
# COMPETENCIES 208, SENTENCES 32
# ------------------------------
# JOB 37, SENTENCE 0 DONE
# JOB 37, SENTENCE 1 DONE
# JOB 37, SENTENCE 2 DONE
# JOB 37, SENTENCE 3 DONE
# JOB 37, SENTENCE 4 DONE
# JOB 37, SENTENCE 5 DONE
# JOB 37, SENTENCE 6 DONE
# JOB 37, SENTENCE 7 DONE
# JOB 37, SENTENCE 8 DONE
# JOB 37, SENTENCE 9 DONE
# JOB 37, SENTENCE 10 DONE
# JOB 37, SENTENCE 11 DONE
# JOB 37, SENTENCE 12 DONE
# JOB 37, SENTENCE 13 DONE
# JOB 37, SENTENCE 14 DONE
# JOB 37, SENTENCE 15 DONE
# JOB 37, SENTENCE 16 DONE
# JOB 37, SENTENCE 17 DONE
# JOB 37, SENTENCE 18 DONE
# JOB 37, SENTENCE 19 DONE
# JOB 37, SENTENCE 20 DONE
# JOB 37, SENTENCE 21 DONE
# JOB 37, SENTENCE 22 DONE
# JOB 37, SENTENCE 23 DONE
# JOB 37, SENTENCE 24 DONE
# JOB 37, SENTENCE 25 DONE
# JOB 37, SENTENCE 26 DONE
# JOB 37, SENTENCE 27 DONE
# JOB 37, SENTENCE 28 DONE
# JOB 37, SENTENCE 29 DONE
# JOB 37, SENTENCE 30 DONE
# JOB 37, SENTENCE 31 DONE
# COMPETENCIES 208, SENTENCES 23
# ------------------------------
# JOB 38, SENTENCE 0 DONE
# JOB 38, SENTENCE 1 DONE
# JOB 38, SENTENCE 2 DONE
# JOB 38, SENTENCE 3 DONE
# JOB 38, SENTENCE 4 DONE
# JOB 38, SENTENCE 5 DONE
# JOB 38, SENTENCE 6 DONE
# JOB 38, SENTENCE 7 DONE
# JOB 38, SENTENCE 8 DONE
# JOB 38, SENTENCE 9 DONE
# JOB 38, SENTENCE 10 DONE
# JOB 38, SENTENCE 11 DONE
# JOB 38, SENTENCE 12 DONE
# JOB 38, SENTENCE 13 DONE
# JOB 38, SENTENCE 14 DONE
# JOB 38, SENTENCE 15 DONE
# JOB 38, SENTENCE 16 DONE
# JOB 38, SENTENCE 17 DONE
# JOB 38, SENTENCE 18 DONE
# JOB 38, SENTENCE 19 DONE
# JOB 38, SENTENCE 20 DONE
# JOB 38, SENTENCE 21 DONE
# JOB 38, SENTENCE 22 DONE
# COMPETENCIES 208, SENTENCES 20
# ------------------------------
# JOB 39, SENTENCE 0 DONE
# JOB 39, SENTENCE 1 DONE
# JOB 39, SENTENCE 2 DONE
# JOB 39, SENTENCE 3 DONE
# JOB 39, SENTENCE 4 DONE
# JOB 39, SENTENCE 5 DONE
# JOB 39, SENTENCE 6 DONE
# JOB 39, SENTENCE 7 DONE
# JOB 39, SENTENCE 8 DONE
# JOB 39, SENTENCE 9 DONE
# JOB 39, SENTENCE 10 DONE
# JOB 39, SENTENCE 11 DONE
# JOB 39, SENTENCE 12 DONE
# JOB 39, SENTENCE 13 DONE
# JOB 39, SENTENCE 14 DONE
# JOB 39, SENTENCE 15 DONE
# JOB 39, SENTENCE 16 DONE
# JOB 39, SENTENCE 17 DONE
# JOB 39, SENTENCE 18 DONE
# JOB 39, SENTENCE 19 DONE
# COMPETENCIES 208, SENTENCES 33
# ------------------------------
# JOB 40, SENTENCE 0 DONE
# JOB 40, SENTENCE 1 DONE
# JOB 40, SENTENCE 2 DONE
# JOB 40, SENTENCE 3 DONE
# JOB 40, SENTENCE 4 DONE
# JOB 40, SENTENCE 5 DONE
# JOB 40, SENTENCE 6 DONE
# JOB 40, SENTENCE 7 DONE
# JOB 40, SENTENCE 8 DONE
# JOB 40, SENTENCE 9 DONE
# JOB 40, SENTENCE 10 DONE
# JOB 40, SENTENCE 11 DONE
# JOB 40, SENTENCE 12 DONE
# JOB 40, SENTENCE 13 DONE
# JOB 40, SENTENCE 14 DONE
# JOB 40, SENTENCE 15 DONE
# JOB 40, SENTENCE 16 DONE
# JOB 40, SENTENCE 17 DONE
# JOB 40, SENTENCE 18 DONE
# JOB 40, SENTENCE 19 DONE
# JOB 40, SENTENCE 20 DONE
# JOB 40, SENTENCE 21 DONE
# JOB 40, SENTENCE 22 DONE
# JOB 40, SENTENCE 23 DONE
# JOB 40, SENTENCE 24 DONE
# JOB 40, SENTENCE 25 DONE
# JOB 40, SENTENCE 26 DONE
# JOB 40, SENTENCE 27 DONE
# JOB 40, SENTENCE 28 DONE
# JOB 40, SENTENCE 29 DONE
# JOB 40, SENTENCE 30 DONE
# JOB 40, SENTENCE 31 DONE
# JOB 40, SENTENCE 32 DONE
# COMPETENCIES 208, SENTENCES 27
# ------------------------------
# JOB 41, SENTENCE 0 DONE
# JOB 41, SENTENCE 1 DONE
# JOB 41, SENTENCE 2 DONE
# JOB 41, SENTENCE 3 DONE
# JOB 41, SENTENCE 4 DONE
# JOB 41, SENTENCE 5 DONE
# JOB 41, SENTENCE 6 DONE
# JOB 41, SENTENCE 7 DONE
# JOB 41, SENTENCE 8 DONE
# JOB 41, SENTENCE 9 DONE
# JOB 41, SENTENCE 10 DONE
# JOB 41, SENTENCE 11 DONE
# JOB 41, SENTENCE 12 DONE
# JOB 41, SENTENCE 13 DONE
# JOB 41, SENTENCE 14 DONE
# JOB 41, SENTENCE 15 DONE
# JOB 41, SENTENCE 16 DONE
# JOB 41, SENTENCE 17 DONE
# JOB 41, SENTENCE 18 DONE
# JOB 41, SENTENCE 19 DONE
# JOB 41, SENTENCE 20 DONE
# JOB 41, SENTENCE 21 DONE
# JOB 41, SENTENCE 22 DONE
# JOB 41, SENTENCE 23 DONE
# JOB 41, SENTENCE 24 DONE
# JOB 41, SENTENCE 25 DONE
# JOB 41, SENTENCE 26 DONE
# COMPETENCIES 208, SENTENCES 20
# ------------------------------
# JOB 42, SENTENCE 0 DONE
# JOB 42, SENTENCE 1 DONE
# JOB 42, SENTENCE 2 DONE
# JOB 42, SENTENCE 3 DONE
# JOB 42, SENTENCE 4 DONE
# JOB 42, SENTENCE 5 DONE
# JOB 42, SENTENCE 6 DONE
# JOB 42, SENTENCE 7 DONE
# JOB 42, SENTENCE 8 DONE
# JOB 42, SENTENCE 9 DONE
# JOB 42, SENTENCE 10 DONE
# JOB 42, SENTENCE 11 DONE
# JOB 42, SENTENCE 12 DONE
# JOB 42, SENTENCE 13 DONE
# JOB 42, SENTENCE 14 DONE
# JOB 42, SENTENCE 15 DONE
# JOB 42, SENTENCE 16 DONE
# JOB 42, SENTENCE 17 DONE
# JOB 42, SENTENCE 18 DONE
# JOB 42, SENTENCE 19 DONE
# COMPETENCIES 208, SENTENCES 20
# ------------------------------
# JOB 43, SENTENCE 0 DONE
# JOB 43, SENTENCE 1 DONE
# JOB 43, SENTENCE 2 DONE
# JOB 43, SENTENCE 3 DONE
# JOB 43, SENTENCE 4 DONE
# JOB 43, SENTENCE 5 DONE
# JOB 43, SENTENCE 6 DONE
# JOB 43, SENTENCE 7 DONE
# JOB 43, SENTENCE 8 DONE
# JOB 43, SENTENCE 9 DONE
# JOB 43, SENTENCE 10 DONE
# JOB 43, SENTENCE 11 DONE
# JOB 43, SENTENCE 12 DONE
# JOB 43, SENTENCE 13 DONE
# JOB 43, SENTENCE 14 DONE
# JOB 43, SENTENCE 15 DONE
# JOB 43, SENTENCE 16 DONE
# JOB 43, SENTENCE 17 DONE
# JOB 43, SENTENCE 18 DONE
# JOB 43, SENTENCE 19 DONE
# COMPETENCIES 208, SENTENCES 27
# ------------------------------
# JOB 44, SENTENCE 0 DONE
# JOB 44, SENTENCE 1 DONE
# JOB 44, SENTENCE 2 DONE
# JOB 44, SENTENCE 3 DONE
# JOB 44, SENTENCE 4 DONE
# JOB 44, SENTENCE 5 DONE
# JOB 44, SENTENCE 6 DONE
# JOB 44, SENTENCE 7 DONE
# JOB 44, SENTENCE 8 DONE
# JOB 44, SENTENCE 9 DONE
# JOB 44, SENTENCE 10 DONE
# JOB 44, SENTENCE 11 DONE
# JOB 44, SENTENCE 12 DONE
# JOB 44, SENTENCE 13 DONE
# JOB 44, SENTENCE 14 DONE
# JOB 44, SENTENCE 15 DONE
# JOB 44, SENTENCE 16 DONE
# JOB 44, SENTENCE 17 DONE
# JOB 44, SENTENCE 18 DONE
# JOB 44, SENTENCE 19 DONE
# JOB 44, SENTENCE 20 DONE
# JOB 44, SENTENCE 21 DONE
# JOB 44, SENTENCE 22 DONE
# JOB 44, SENTENCE 23 DONE
# JOB 44, SENTENCE 24 DONE
# JOB 44, SENTENCE 25 DONE
# JOB 44, SENTENCE 26 DONE
# COMPETENCIES 208, SENTENCES 11
# ------------------------------
# JOB 45, SENTENCE 0 DONE
# JOB 45, SENTENCE 1 DONE
# JOB 45, SENTENCE 2 DONE
# JOB 45, SENTENCE 3 DONE
# JOB 45, SENTENCE 4 DONE
# JOB 45, SENTENCE 5 DONE
# JOB 45, SENTENCE 6 DONE
# JOB 45, SENTENCE 7 DONE
# JOB 45, SENTENCE 8 DONE
# JOB 45, SENTENCE 9 DONE
# JOB 45, SENTENCE 10 DONE
# COMPETENCIES 208, SENTENCES 32
# ------------------------------
# JOB 46, SENTENCE 0 DONE
# JOB 46, SENTENCE 1 DONE
# JOB 46, SENTENCE 2 DONE
# JOB 46, SENTENCE 3 DONE
# JOB 46, SENTENCE 4 DONE
# JOB 46, SENTENCE 5 DONE
# JOB 46, SENTENCE 6 DONE
# JOB 46, SENTENCE 7 DONE
# JOB 46, SENTENCE 8 DONE
# JOB 46, SENTENCE 9 DONE
# JOB 46, SENTENCE 10 DONE
# JOB 46, SENTENCE 11 DONE
# JOB 46, SENTENCE 12 DONE
# JOB 46, SENTENCE 13 DONE
# JOB 46, SENTENCE 14 DONE
# JOB 46, SENTENCE 15 DONE
# JOB 46, SENTENCE 16 DONE
# JOB 46, SENTENCE 17 DONE
# JOB 46, SENTENCE 18 DONE
# JOB 46, SENTENCE 19 DONE
# JOB 46, SENTENCE 20 DONE
# JOB 46, SENTENCE 21 DONE
# JOB 46, SENTENCE 22 DONE
# JOB 46, SENTENCE 23 DONE
# JOB 46, SENTENCE 24 DONE
# JOB 46, SENTENCE 25 DONE
# JOB 46, SENTENCE 26 DONE
# JOB 46, SENTENCE 27 DONE
# JOB 46, SENTENCE 28 DONE
# JOB 46, SENTENCE 29 DONE
# JOB 46, SENTENCE 30 DONE
# JOB 46, SENTENCE 31 DONE
# COMPETENCIES 208, SENTENCES 15
# ------------------------------
# JOB 47, SENTENCE 0 DONE
# JOB 47, SENTENCE 1 DONE
# JOB 47, SENTENCE 2 DONE
# JOB 47, SENTENCE 3 DONE
# JOB 47, SENTENCE 4 DONE
# JOB 47, SENTENCE 5 DONE
# JOB 47, SENTENCE 6 DONE
# JOB 47, SENTENCE 7 DONE
# JOB 47, SENTENCE 8 DONE
# JOB 47, SENTENCE 9 DONE
# JOB 47, SENTENCE 10 DONE
# JOB 47, SENTENCE 11 DONE
# JOB 47, SENTENCE 12 DONE
# JOB 47, SENTENCE 13 DONE
# JOB 47, SENTENCE 14 DONE
# COMPETENCIES 208, SENTENCES 32
# ------------------------------
# JOB 48, SENTENCE 0 DONE
# JOB 48, SENTENCE 1 DONE
# JOB 48, SENTENCE 2 DONE
# JOB 48, SENTENCE 3 DONE
# JOB 48, SENTENCE 4 DONE
# JOB 48, SENTENCE 5 DONE
# JOB 48, SENTENCE 6 DONE
# JOB 48, SENTENCE 7 DONE
# JOB 48, SENTENCE 8 DONE
# JOB 48, SENTENCE 9 DONE
# JOB 48, SENTENCE 10 DONE
# JOB 48, SENTENCE 11 DONE
# JOB 48, SENTENCE 12 DONE
# JOB 48, SENTENCE 13 DONE
# JOB 48, SENTENCE 14 DONE
# JOB 48, SENTENCE 15 DONE
# JOB 48, SENTENCE 16 DONE
# JOB 48, SENTENCE 17 DONE
# JOB 48, SENTENCE 18 DONE
# JOB 48, SENTENCE 19 DONE
# JOB 48, SENTENCE 20 DONE
# JOB 48, SENTENCE 21 DONE
# JOB 48, SENTENCE 22 DONE
# JOB 48, SENTENCE 23 DONE
# JOB 48, SENTENCE 24 DONE
# JOB 48, SENTENCE 25 DONE
# JOB 48, SENTENCE 26 DONE
# JOB 48, SENTENCE 27 DONE
# JOB 48, SENTENCE 28 DONE
# JOB 48, SENTENCE 29 DONE
# JOB 48, SENTENCE 30 DONE
# JOB 48, SENTENCE 31 DONE
# COMPETENCIES 208, SENTENCES 30
# ------------------------------
# JOB 49, SENTENCE 0 DONE
# JOB 49, SENTENCE 1 DONE
# JOB 49, SENTENCE 2 DONE
# JOB 49, SENTENCE 3 DONE
# JOB 49, SENTENCE 4 DONE
# JOB 49, SENTENCE 5 DONE
# JOB 49, SENTENCE 6 DONE
# JOB 49, SENTENCE 7 DONE
# JOB 49, SENTENCE 8 DONE
# JOB 49, SENTENCE 9 DONE
# JOB 49, SENTENCE 10 DONE
# JOB 49, SENTENCE 11 DONE
# JOB 49, SENTENCE 12 DONE
# JOB 49, SENTENCE 13 DONE
# JOB 49, SENTENCE 14 DONE
# JOB 49, SENTENCE 15 DONE
# JOB 49, SENTENCE 16 DONE
# JOB 49, SENTENCE 17 DONE
# JOB 49, SENTENCE 18 DONE
# JOB 49, SENTENCE 19 DONE
# JOB 49, SENTENCE 20 DONE
# JOB 49, SENTENCE 21 DONE
# JOB 49, SENTENCE 22 DONE
# JOB 49, SENTENCE 23 DONE
# JOB 49, SENTENCE 24 DONE
# JOB 49, SENTENCE 25 DONE
# JOB 49, SENTENCE 26 DONE
# JOB 49, SENTENCE 27 DONE
# JOB 49, SENTENCE 28 DONE
# JOB 49, SENTENCE 29 DONE

# %%
competency = []
for i in range(len(scores)):
    tup = list(zip(scores[i], comp_ids[i]))
    tup.sort(reverse=True)

    top = []
    visited = []
    for t in tup:
        if t[1] not in visited:
            top.append(t)
            visited.append(t[1])

    idss = [x[1] for x in top]
    if len(idss) > 20:
        idss = idss[:20]

    competency_names = []
    for ids in idss:
        competency_names.append(onet_df['category'].iloc[ids] + " | " + \
                                onet_df['competency'].iloc[ids] + " | " + \
                                onet_df['description'].iloc[ids])

    competency.append(competency_names)

# %%
result_df = occupations.iloc[job_ids[:FIRST_N]]

# %%
result_df['onet_competency'] = competency

# %%
result_df.head()
# Out:
#    id                          title  identifier  score_all  \
# 0   1                 Data Scientist  15-1111.00   0.883895
# 1   2  Business Intelligence Analyst  15-1199.08   0.866399
# 4   5      Machine Learning Engineer  15-1111.00   0.847708
# 5   6                 Data Scientist  15-1111.00   0.846623
# 6   7       Associate Data Scientist  15-1111.00   0.872069
#
#                                            name  \
# 0  Computer and Information Research Scientists
# 1                Business Intelligence Analysts
# 4  Computer and Information Research Scientists
# 5  Computer and Information Research Scientists
# 6  Computer and Information Research Scientists
#
#                                          description  \
# 0  Do you want a meaningful role in a company tha...
# 1  Brand: Glentel Corporate\nLocation: Burnaby Of...
# 4  Who We are\nFounded in 2016, Skycope Technolog...
# 5  BrainStation is a global leader in digital ski...
# 6  We are looking for a Data Scientist to support...
#
#                                      onet_competency
# 0  [Knowledge | Administration and Management | K...
# 1  [Abilities | Inductive Reasoning | The ability...
# 4  [Knowledge | Administration and Management | K...
# 5  [Knowledge | Administration and Management | K...
# 6  [Knowledge | Administration and Management | K...

# %%
# Save file
result_df.to_csv('results/skills.csv', index=False)

# %%
# Compare result of 2 different occupations
print("COMPUTER AND INFORMATION RESEARCH SCIENTISTS")
for i, comp in enumerate(result_df['onet_competency'].iloc[0]):
    print("{}. {}".format(str(i+1), comp))
print("\n----------------------------------------\n")
print("BUSINESS INTELLIGENCE ANALYSTS:")
for i, comp in enumerate(result_df['onet_competency'].iloc[1]):
    print("{}. {}".format(str(i+1), comp))
# Out:
# COMPUTER AND INFORMATION RESEARCH SCIENTISTS
# 1. Knowledge | Administration and Management | Knowledge of business and management principles involved in strategic planning, resource allocation, human resources modeling, leadership technique, production methods, and coordination of people and resources.
# 2. Abilities | Fluency of Ideas | The ability to come up with a number of ideas about a topic (the number of ideas is important, not their quality, correctness, or creativity).
# 3. Technology Skills | Data visualization software | Analytical or scientific software
# 4. Knowledge | Computers and Electronics | Knowledge of circuit boards, processors, chips, electronic equipment, and computer hardware and software, including applications and programming.
# 5. Knowledge | English Language | Knowledge of the structure and content of the English language including the meaning and spelling of words, rules of composition, and grammar.
# 6. Technology Skills | PostgreSQL | Object oriented data base management software
# 7. Technology Skills | Waikato Environment for Knowledge Analysis Weka | Graphical user interface development software
# 8. Skills | Active Listening | Giving full attention to what other people are saying, taking time to understand the points being made, asking questions as appropriate, and not interrupting at inappropriate times.
# 9. Abilities | Near Vision | The ability to see details at close range (within a few feet of the observer).
# 10. Technology Skills | Data entry software | Data base user interface and query software
# 11. Technology Skills | Practical extraction and reporting language Perl | Object or component oriented development software
# 12. Skills | Active Learning | Understanding the implications of new information for both current and future problem-solving and decision-making.
# 13. Technology Skills | Plug-in file software | Web page creation and editing software
# 14. Tools Used | Microcomputers | Microprocessors
# 15. Technology Skills | Intel Integrated Performance Primitives | Development environment software
# 16. Technology Skills | Geographic information system GIS software | Map creation software
# 17. Technology Skills | Google Analytics | Data mining software
# 18. Technology Skills | Microsoft Office | Office suite software
# 19. Technology Skills | Intel Math Kernel Library | Analytical or scientific software
# 20. Skills | Critical Thinking | Using logic and reasoning to identify the strengths and weaknesses of alternative solutions, conclusions or approaches to problems.
#
# ----------------------------------------
#
# BUSINESS INTELLIGENCE ANALYSTS:
# 1. Abilities | Inductive Reasoning | The ability to combine pieces of information to form general rules or conclusions (includes finding a relationship among seemingly unrelated events).
# 2. Knowledge | Administration and Management | Knowledge of business and management principles involved in strategic planning, resource allocation, human resources modeling, leadership technique, production methods, and coordination of people and resources.
# 3. Abilities | Flexibility of Closure | The ability to identify or detect a known pattern (a figure, object, word, or sound) that is hidden in other distracting material.
# 4. Knowledge | Computers and Electronics | Knowledge of circuit boards, processors, chips, electronic equipment, and computer hardware and software, including applications and programming.
# 5. Technology Skills | Oracle Business Intelligence Enterprise Edition | Business intelligence and data analysis software
# 6. Technology Skills | Transact-SQL | Data base user interface and query software
# 7. Technology Skills | Unified modeling language UML | Requirements analysis and system architecture software
# 8. Knowledge | Communications and Media | Knowledge of media production, communication, and dissemination techniques and methods. This includes alternative ways to inform and entertain via written, oral, and visual media.
# 9. Technology Skills | IBM Power Systems software | Enterprise system management software
# 10. Abilities | Fluency of Ideas | The ability to come up with a number of ideas about a topic (the number of ideas is important, not their quality, correctness, or creativity).
# 11. Abilities | Written Comprehension | The ability to read and understand information and ideas presented in writing.
# 12. Technology Skills | Virtual private networking VPN software | Network security and virtual private network VPN equipment software
# 13. Tools Used | Scanners | Scanners
# 14. Technology Skills | Apache HTTP Server | Portal server software
# 15. Technology Skills | Microsoft SharePoint | Project management software
# 16. Abilities | Oral Comprehension | The ability to listen to and understand information and ideas presented through spoken words and sentences.
# 17. Technology Skills | Drupal | Web platform development software
# 18. Technology Skills | Adobe Systems Adobe Flash | Graphics or photo imaging software
# 19. Technology Skills | Adobe Systems Adobe ActionScript | Development environment software
# 20. Technology Skills | Dynamic hypertext markup language DHTML | Web platform development software

# %%
# Compare result of 2 same occupations

# Some of the unique competencies are:
# Technology Skills | Unified modeling language UML
# Technology Skills | Sun Microsystems Java 2 Platform Enterprise Edition J2EE 
# Technology Skills | Plug-in file software | Web page creation and editing software


print("COMPUTER AND INFORMATION RESEARCH SCIENTISTS")
for i, comp in enumerate(result_df['onet_competency'].iloc[0]):
    print("{}. {}".format(str(i+1), comp))
print("\n----------------------------------------\n")
print("COMPUTER AND INFORMATION RESEARCH SCIENTISTS:")
for i, comp in enumerate(result_df['onet_competency'].iloc[2]):
    print("{}. {}".format(str(i+1), comp))
# Out:
# COMPUTER AND INFORMATION RESEARCH SCIENTISTS
# 1. Knowledge | Administration and Management | Knowledge of business and management principles involved in strategic planning, resource allocation, human resources modeling, leadership technique, production methods, and coordination of people and resources.
# 2. Abilities | Fluency of Ideas | The ability to come up with a number of ideas about a topic (the number of ideas is important, not their quality, correctness, or creativity).
# 3. Technology Skills | Data visualization software | Analytical or scientific software
# 4. Knowledge | Computers and Electronics | Knowledge of circuit boards, processors, chips, electronic equipment, and computer hardware and software, including applications and programming.
# 5. Knowledge | English Language | Knowledge of the structure and content of the English language including the meaning and spelling of words, rules of composition, and grammar.
# 6. Technology Skills | PostgreSQL | Object oriented data base management software
# 7. Technology Skills | Waikato Environment for Knowledge Analysis Weka | Graphical user interface development software
# 8. Skills | Active Listening | Giving full attention to what other people are saying, taking time to understand the points being made, asking questions as appropriate, and not interrupting at inappropriate times.
# 9. Abilities | Near Vision | The ability to see details at close range (within a few feet of the observer).
# 10. Technology Skills | Data entry software | Data base user interface and query software
# 11. Technology Skills | Practical extraction and reporting language Perl | Object or component oriented development software
# 12. Skills | Active Learning | Understanding the implications of new information for both current and future problem-solving and decision-making.
# 13. Technology Skills | Plug-in file software | Web page creation and editing software
# 14. Tools Used | Microcomputers | Microprocessors
# 15. Technology Skills | Intel Integrated Performance Primitives | Development environment software
# 16. Technology Skills | Geographic information system GIS software | Map creation software
# 17. Technology Skills | Google Analytics | Data mining software
# 18. Technology Skills | Microsoft Office | Office suite software
# 19. Technology Skills | Intel Math Kernel Library | Analytical or scientific software
# 20. Skills | Critical Thinking | Using logic and reasoning to identify the strengths and weaknesses of alternative solutions, conclusions or approaches to problems.
#
# ----------------------------------------
#
# COMPUTER AND INFORMATION RESEARCH SCIENTISTS:
# 1. Knowledge | Administration and Management | Knowledge of business and management principles involved in strategic planning, resource allocation, human resources modeling, leadership technique, production methods, and coordination of people and resources.
# 2. Knowledge | Computers and Electronics | Knowledge of circuit boards, processors, chips, electronic equipment, and computer hardware and software, including applications and programming.
# 3. Knowledge | English Language | Knowledge of the structure and content of the English language including the meaning and spelling of words, rules of composition, and grammar.
# 4. Technology Skills | Waikato Environment for Knowledge Analysis Weka | Graphical user interface development software
# 5. Skills | Technology Design | Generating or adapting equipment and technology to serve user needs.
# 6. Abilities | Number Facility | The ability to add, subtract, multiply, or divide quickly and correctly.
# 7. Tools Used | Universal serial bus USB flash drives | High capacity removable media drives
# 8. Abilities | Near Vision | The ability to see details at close range (within a few feet of the observer).
# 9. Skills | Active Listening | Giving full attention to what other people are saying, taking time to understand the points being made, asking questions as appropriate, and not interrupting at inappropriate times.
# 10. Technology Skills | Unified modeling language UML | Requirements analysis and system architecture software
# 11. Technology Skills | Geographic information system GIS software | Map creation software
# 12. Technology Skills | Three-dimensional 3D graphics software | Graphics or photo imaging software
# 13. Abilities | Fluency of Ideas | The ability to come up with a number of ideas about a topic (the number of ideas is important, not their quality, correctness, or creativity).
# 14. Technology Skills | Intel Integrated Performance Primitives | Development environment software
# 15. Technology Skills | Sun Microsystems Java 2 Platform Enterprise Edition J2EE | Development environment software
# 16. Abilities | Inductive Reasoning | The ability to combine pieces of information to form general rules or conclusions (includes finding a relationship among seemingly unrelated events).
# 17. Skills | Social Perceptiveness | Being aware of others' reactions and understanding why they react as they do.
# 18. Technology Skills | Mathematical software | Analytical or scientific software
# 19. Technology Skills | Apache Hive | Data base user interface and query software
# 20. Skills | Judgment and Decision Making | Considering the relative costs and benefits of potential actions to choose the most appropriate one.
